# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Practice Projects\medical_cost_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# Here, we can see that, 'charges' is depend on all the other variables such as 'age','sex','bmi','children','smoker' and'region'. Hence, we can take 'cherges' as our label and other variables as our xlabels.

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.sample()
# Out:
#      age   sex     bmi  children smoker     region      charges
# 752   64  male  37.905         0     no  northwest  14210.53595

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df['bmi']=pd.DataFrame(df['bmi'].astype(int))
df
# Out:
#       age     sex  bmi  children smoker     region      charges
# 0      19  female   27         0    yes  southwest  16884.92400
# 1      18    male   33         1     no  southeast   1725.55230
# 2      28    male   33         3     no  southeast   4449.46200
# 3      33    male   22         0     no  northwest  21984.47061
# 4      32    male   28         0     no  northwest   3866.85520
# ...   ...     ...  ...       ...    ...        ...          ...
# 1333   50    male   30         3     no  northwest  10600.54830
# 1334   18  female   31         0     no  northeast   2205.98080
# 1335   18  female   36         0     no  southeast   1629.83350
# 1336   21  female   25         0     no  southwest   2007.94500
# 1337   61  female   29         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Here, we have changed the dtype of bmi from flaot to int to get the things smoother.

# %%
df['charges']=pd.DataFrame(df['charges'].astype(int))
df
# Out:
#       age     sex  bmi  children smoker     region  charges
# 0      19  female   27         0    yes  southwest    16884
# 1      18    male   33         1     no  southeast     1725
# 2      28    male   33         3     no  southeast     4449
# 3      33    male   22         0     no  northwest    21984
# 4      32    male   28         0     no  northwest     3866
# ...   ...     ...  ...       ...    ...        ...      ...
# 1333   50    male   30         3     no  northwest    10600
# 1334   18  female   31         0     no  northeast     2205
# 1335   18  female   36         0     no  southeast     1629
# 1336   21  female   25         0     no  southwest     2007
# 1337   61  female   29         0    yes  northwest    29141
#
# [1338 rows x 7 columns]

# %% [markdown]
# Here, we also have changed the dtype of charges from flaot to int to get the things smoother.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.169656     1.094918  13269.928999
# std      14.049960     6.119875     1.205493  12110.012755
# min      18.000000    15.000000     0.000000   1121.000000
# 25%      27.000000    26.000000     0.000000   4740.000000
# 50%      39.000000    30.000000     1.000000   9381.500000
# 75%      51.000000    34.000000     2.000000  16639.250000
# max      64.000000    53.000000     5.000000  63770.000000

# %% [markdown]
# from the above description we can see that,
# -median(75%) id greater than mean(50%).
# -There is a difference between 75% and max values values which means that the outliers are present in the data.
# -we can also see the details of std deviation, count , min values in the above data.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel('features',fontsize=10)
plt.ylabel('Description factor',fontsize=10)
plt.title('Description graph',fontsize=20)
plt.show()

# %% [markdown]
# From the above heatmap, we can see thatthe count of all the variables are same.

# %%
sns.regplot(x='age',y='charges',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.regplot(x='bmi',y='charges',data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x='children',y='charges',data=df)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
sns.pairplot(data=df,palette='dark')

# %%
df
# Out:
#       age     sex  bmi  children smoker     region  charges
# 0      19  female   27         0    yes  southwest    16884
# 1      18    male   33         1     no  southeast     1725
# 2      28    male   33         3     no  southeast     4449
# 3      33    male   22         0     no  northwest    21984
# 4      32    male   28         0     no  northwest     3866
# ...   ...     ...  ...       ...    ...        ...      ...
# 1333   50    male   30         3     no  northwest    10600
# 1334   18  female   31         0     no  northeast     2205
# 1335   18  female   36         0     no  southeast     1629
# 1336   21  female   25         0     no  southwest     2007
# 1337   61  female   29         0    yes  northwest    29141
#
# [1338 rows x 7 columns]

# %% [markdown]
# From the above boxplot, we can see that outliers are present in bmi' and 'charges'columns.

# %% [markdown]
# For removing the outliers, we are going to use zscore and IQR methods before building the model and selecting the best one.

# %%
from scipy.stats import zscore
outliers=df[['age','bmi','children']]
z=np.abs(zscore(outliers))
z
# Out:
#            age       bmi  children
# 0     1.438764  0.518122  0.908614
# 1     1.509965  0.462657  0.078767
# 2     0.797954  0.462657  1.580926
# 3     0.441948  1.335438  0.908614
# 4     0.513149  0.354659  0.908614
# ...        ...       ...       ...
# 1333  0.768473  0.027733  1.580926
# 1334  1.509965  0.135731  0.908614
# 1335  1.509965  0.953046  0.908614
# 1336  1.296362  0.845048  0.908614
# 1337  1.551686  0.191196  0.908614
#
# [1338 rows x 3 columns]

# %%
np.where(z>3)
# Out:
# (array([  32,   71,  116,  166,  413,  425,  438,  568,  640,  847,  877,
#          932,  937,  969,  984, 1047, 1085, 1116, 1130, 1245, 1272, 1317],
#        dtype=int64),
#  array([2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1],
#        dtype=int64))

# %%
z.iloc[71,1]
# Out:
# 0.3546587836144213

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (1316, 7)

# %%
print('old dataset:',df.shape[0])
print('new dataset:',df1.shape[0])
# Out:
# old dataset: 1338
# new dataset: 1316

# %%
print('Data Loss Percentage:',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage: 1.6442451420029895

# %% [markdown]
# The above loss of data percentage is very low, which is affordable. No we can proceed for IQR method.

# %%
df1=df
df
# Out:
#       age     sex  bmi  children smoker     region  charges
# 0      19  female   27         0    yes  southwest    16884
# 1      18    male   33         1     no  southeast     1725
# 2      28    male   33         3     no  southeast     4449
# 3      33    male   22         0     no  northwest    21984
# 4      32    male   28         0     no  northwest     3866
# ...   ...     ...  ...       ...    ...        ...      ...
# 1333   50    male   30         3     no  northwest    10600
# 1334   18  female   31         0     no  northeast     2205
# 1335   18  female   36         0     no  southeast     1629
# 1336   21  female   25         0     no  southwest     2007
# 1337   61  female   29         0    yes  northwest    29141
#
# [1338 rows x 7 columns]

# %%
df=df.replace({'sex':{'female':1,'male':0}})
df
# Out:
#       age  sex  bmi  children smoker     region  charges
# 0      19    1   27         0    yes  southwest    16884
# 1      18    0   33         1     no  southeast     1725
# 2      28    0   33         3     no  southeast     4449
# 3      33    0   22         0     no  northwest    21984
# 4      32    0   28         0     no  northwest     3866
# ...   ...  ...  ...       ...    ...        ...      ...
# 1333   50    0   30         3     no  northwest    10600
# 1334   18    1   31         0     no  northeast     2205
# 1335   18    1   36         0     no  southeast     1629
# 1336   21    1   25         0     no  southwest     2007
# 1337   61    1   29         0    yes  northwest    29141
#
# [1338 rows x 7 columns]

# %%
df=df.replace({'smoker':{'yes':1,'no':0}})
df
# Out:
#       age  sex  bmi  children  smoker     region  charges
# 0      19    1   27         0       1  southwest    16884
# 1      18    0   33         1       0  southeast     1725
# 2      28    0   33         3       0  southeast     4449
# 3      33    0   22         0       0  northwest    21984
# 4      32    0   28         0       0  northwest     3866
# ...   ...  ...  ...       ...     ...        ...      ...
# 1333   50    0   30         3       0  northwest    10600
# 1334   18    1   31         0       0  northeast     2205
# 1335   18    1   36         0       0  southeast     1629
# 1336   21    1   25         0       0  southwest     2007
# 1337   61    1   29         0       1  northwest    29141
#
# [1338 rows x 7 columns]

# %%
df.dtypes
# Out:
# age          int64
# sex          int64
# bmi          int32
# children     int64
# smoker       int64
# region      object
# charges      int32
# dtype: object

# %%
pd.unique(df['region'])
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df=df.replace({'region':{'southwest':0,'southeast':1,'northwest':2,'northeast':3}})
df
# Out:
#       age  sex  bmi  children  smoker  region  charges
# 0      19    1   27         0       1       0    16884
# 1      18    0   33         1       0       1     1725
# 2      28    0   33         3       0       1     4449
# 3      33    0   22         0       0       2    21984
# 4      32    0   28         0       0       2     3866
# ...   ...  ...  ...       ...     ...     ...      ...
# 1333   50    0   30         3       0       2    10600
# 1334   18    1   31         0       0       3     2205
# 1335   18    1   36         0       0       1     1629
# 1336   21    1   25         0       0       0     2007
# 1337   61    1   29         0       1       2    29141
#
# [1338 rows x 7 columns]

# %%
Q1=outliers.quantile(0.25)
Q3=outliers.quantile(0.75)
IQR=Q3-Q1
df2=df[~((df<(Q1-1.5*IQR)))|(df>(Q3+1.5*IQR)).any(axis=1)]
df2
# Out:
#       age  sex  bmi  children  smoker  region  charges
# 0      19    1   27         0       1       0    16884
# 1      18    0   33         1       0       1     1725
# 2      28    0   33         3       0       1     4449
# 3      33    0   22         0       0       2    21984
# 4      32    0   28         0       0       2     3866
# ...   ...  ...  ...       ...     ...     ...      ...
# 1333   50    0   30         3       0       2    10600
# 1334   18    1   31         0       0       3     2205
# 1335   18    1   36         0       0       1     1629
# 1336   21    1   25         0       0       0     2007
# 1337   61    1   29         0       1       2    29141
#
# [1338 rows x 7 columns]

# %% [markdown]
# From the above IQR calculations, we have found out the outliers present in the data.

# %%
plt.figure(figsize=(35,20))
p=1
for column in df:
    if p<=18:
        ax=plt.subplot(6,4,p)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    p+=1
plt.show()

# %%
q1=df['bmi'].quantile(0.25)
q3=df['bmi'].quantile(0.75)
IQR=q3-q1
low=q1-1.5*IQR
up=q3+1.5*IQR

up_array=np.where(df['bmi']>=up)[0]
print(up_array)

df
# Out:
# [ 116  286  401  438  454  543  547  549  660  847  860  930  941 1047
#  1088 1317]
#       age  sex  bmi  children  smoker  region  charges
# 0      19    1   27         0       1       0    16884
# 1      18    0   33         1       0       1     1725
# 2      28    0   33         3       0       1     4449
# 3      33    0   22         0       0       2    21984
# 4      32    0   28         0       0       2     3866
# ...   ...  ...  ...       ...     ...     ...      ...
# 1333   50    0   30         3       0       2    10600
# 1334   18    1   31         0       0       3     2205
# 1335   18    1   36         0       0       1     1629
# 1336   21    1   25         0       0       0     2007
# 1337   61    1   29         0       1       2    29141
#
# [1338 rows x 7 columns]

# %%
df[df['bmi']>up].count()
# Out:
# age         9
# sex         9
# bmi         9
# children    9
# smoker      9
# region      9
# charges     9
# dtype: int64

# %% [markdown]
# From the above data, firstly we have returned the rows, then with the help of count function , the total number of rows were 9.

# %% [markdown]
# Now, we will do the trimmimg of the data, to remove all the bad data from the dataset.

# %%
new_df=df[df['bmi']<up]
new_df.shape
# Out:
# (1322, 7)

# %%
plt.figure(figsize=(20,12))
plt.subplot(5,4,3)
sns.histplot(df['bmi'],kde=True)

plt.show()

# %% [markdown]
# The above plot shows almost normal distribution.

# %%
new_df.skew()
# Out:
# age         0.060592
# sex         0.018176
# bmi         0.097467
# children    0.933169
# smoker      1.468961
# region      0.024851
# charges     1.497919
# dtype: float64

# %%
sns.distplot(df['charges'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Density'>

# %%
plt.figure(figsize=(25,18))
p=1
for i in df:
    if p<=18:
        ax=plt.subplot(6,4,p)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=20)
    p+=1
plt.show()

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.108437  0.042469 -0.025019 -0.002127  0.299009
# sex       0.020856  1.000000 -0.046503 -0.017163 -0.076185  0.004588 -0.057293
# bmi       0.108437 -0.046503  1.000000  0.011097  0.001669 -0.159830  0.196188
# children  0.042469 -0.017163  0.011097  1.000000  0.007673 -0.016569  0.067999
# smoker   -0.025019 -0.076185  0.001669  0.007673  1.000000  0.002181  0.787251
# region   -0.002127  0.004588 -0.159830 -0.016569  0.002181  1.000000  0.006209
# charges   0.299009 -0.057293  0.196188  0.067999  0.787251  0.006209  1.000000

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features name',fontsize=14)
plt.title('Descriptive plot',fontsize=20)

plt.show()

# %%
df.corr().bmi.sort_values()
# Out:
# region     -0.159830
# sex        -0.046503
# smoker      0.001669
# children    0.011097
# age         0.108437
# charges     0.196188
# bmi         1.000000
# Name: bmi, dtype: float64

# %%
x=new_df.drop('bmi',axis=1)
y=new_df['bmi']
print('Feature dimension',x.shape)
print('Target dimension',y.shape)
# Out:
# Feature dimension (1322, 6)
# Target dimension (1322,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex  children    smoker    region   charges
# 0    -1.435961  1.009119 -0.906695  1.973904 -1.345164  0.306511
# 1    -1.507086 -0.990964 -0.076029 -0.506610 -0.442470 -0.958505
# 2    -0.795831 -0.990964  1.585303 -0.506610 -0.442470 -0.731188
# 3    -0.440204 -0.990964 -0.906695 -0.506610  0.460224  0.732105
# 4    -0.511329 -0.990964 -0.906695 -0.506610  0.460224 -0.779839
# ...        ...       ...       ...       ...       ...       ...
# 1317  0.768930 -0.990964  1.585303 -0.506610  0.460224 -0.217888
# 1318 -1.507086  1.009119 -0.906695 -0.506610  1.362917 -0.918449
# 1319 -1.507086  1.009119 -0.906695 -0.506610 -0.442470 -0.966516
# 1320 -1.293710  1.009119 -0.906695 -0.506610 -1.345164 -0.934972
# 1321  1.551311  1.009119 -0.906695  1.973904  0.460224  1.329355
#
# [1322 rows x 6 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF values  Features
# 0    1.371254       age
# 1    1.007472       sex
# 2    1.011977  children
# 3    3.268625    smoker
# 4    1.000540    region
# 5    3.606114   charges

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Creating Train test split

# %%
maxacc=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print('max r2 score is :',maxacc,'on random state :',maxrs)
# Out:
# max r2 score is : 0.1713630552106462 on random state : 116

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr_test=lr.predict(x_test)
lr_train=lr.predict(x_train)
print('r2_score',r2_score(y_test,lr_test))
print('r2 score on training data',r2_score(y_train,lr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,lr_test))
print('mean squared error',mean_squared_error(y_test,lr_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,lr_test)))
# Out:
# r2_score 0.1265988788889154
# r2 score on training data 13.308604544558357
# mean absolute error 4.4769355098740995
# mean squared error 31.020926468811396
# root mean squared error 5.569643298166535

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
LR_test=LR.predict(x_test)
LR_train=LR.predict(x_train)
print('r2 score:',r2_score(y_test,LR_test))
print('r2 score on training data:',r2_score(y_train,LR_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,LR_test))
print('mean squared error:',mean_squared_error(y_test,LR_test))
print('root mean sqaured error:',np.sqrt(mean_squared_error(y_test,LR_test)))
# Out:
# r2 score: 0.1265988788889154
# r2 score on training data: 13.308604544558357
# mean absolute error: 4.4769355098740995
# mean squared error: 31.020926468811396
# root mean sqaured error: 5.569643298166535

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=LR_test,y=y_test,color='r')
plt.plot(LR_test,LR_test,color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('linear regression',fontsize=14)
plt.title('Linear Regression',fontsize=20)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_test=rfr.predict(x_test)
rfr_train=rfr.predict(x_train)
print('r2 score',r2_score(y_test,rfr_test))
print('r2 score on training data',r2_score(y_train,rfr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,rfr_test))
print('mean squared error',mean_squared_error(y_test,rfr_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,rfr_test)))
# Out:
# r2 score 0.038092688570344424
# r2 score on training data 88.03645678120834
# mean absolute error 4.545184718723761
# mean squared error 34.16443516778617
# root mean squared error 5.845035086959374

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knn_test=knn.predict(x_test)
knn_train=knn.predict(x_train)
print('r2 score', r2_score(y_test,knn_test))
print('r2 score on training data',r2_score(y_train,knn_train)*100)
print('mean absolute error',mean_absolute_error(y_test,knn_test))
print('mean squared error',mean_squared_error(y_test,knn_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,knn_test)))
# Out:
# r2 score -0.007849206661117103
# r2 score on training data 43.90880825857293
# mean absolute error 4.679596977329975
# mean squared error 35.79617128463477
# root mean squared error 5.982990162505264

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr_test=gbr.predict(x_test)
gbr_train=gbr.predict(x_train)
print('r2 score', r2_score(y_test,gbr_test))
print('r2 score on training data',r2_score(y_train,gbr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,gbr_test))
print('mean squared error',mean_squared_error(y_test,gbr_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,gbr_test)))
# Out:
# r2 score 0.16509280200341514
# r2 score on training data 44.01039340769457
# mean absolute error 4.295589596505467
# mean squared error 29.653722867204042
# root mean squared error 5.44552319499275

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
lasso_test=lasso.predict(x_test)
lasso_train=lasso.predict(x_train)
print('r2_score',r2_score(y_test,lasso_test))
print('r2 score on training data',r2_score(y_train,lasso_train)*100)
print('mean absolute error',mean_absolute_error(y_test,lasso_test))
print('mean squared error',mean_squared_error(y_test,lasso_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,lasso_test)))
# Out:
# r2_score 0.007026288898754007
# r2 score on training data 1.4250909233273434
# mean absolute error 4.814543460015841
# mean squared error 35.267832537642015
# root mean swuared error 5.938672624218481

# %%
from sklearn.linear_model import Ridge

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
rdg_test=rdg.predict(x_test)
rdg_train=rdg.predict(x_train)
print('r2_score',r2_score(y_test,rdg_test))
print('r2 score on training data',r2_score(y_train,rdg_train)*100)
print('mean absolute error',mean_absolute_error(y_test,rdg_test))
print('mean squared error',mean_squared_error(y_test,rdg_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,rdg_test)))
# Out:
# r2_score 0.12651730825280016
# r2 score on training data 13.308176371439961
# mean absolute error 4.477562083849805
# mean squared error 31.02382364474097
# root mean swuared error 5.569903378402624

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr_test=dtr.predict(x_test)
dtr_train=dtr.predict(x_train)
print('r2_score',r2_score(y_test,dtr_test))
print('r2 score on training data',r2_score(y_train,dtr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,dtr_test))
print('mean squared error',mean_squared_error(y_test,dtr_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,dtr_test)))
# Out:
# r2_score -0.4625468482598709
# r2 score on training data 99.99676704847184
# mean absolute error 5.551637279596977
# mean squared error 51.94584382871537
# root mean swuared error 7.207346517874339

# %%
from sklearn.svm import SVR

# %%
svr=SVR()
svr.fit(x_train,y_train)
svr_test=svr.predict(x_test)
svr_train=svr.predict(x_train)
print('r2_score',r2_score(y_test,svr_test))
print('r2 score on training data',r2_score(y_train,svr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,svr_test))
print('mean squared error',mean_squared_error(y_test,svr_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,svr_test)))
# Out:
# r2_score 0.14020899903349016
# r2 score on training data 22.651184220057374
# mean absolute error 4.403651673768028
# mean squared error 30.537530551366903
# root mean swuared error 5.526077320429646

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
etr_test=etr.predict(x_test)
etr_train=etr.predict(x_train)
print('r2 score',r2_score(y_test,etr_test))
print('r2 score on training data',r2_score(y_train,etr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,etr_test))
print('mean squared error',mean_squared_error(y_test,etr_test))
print('mean root sqaured error',np.sqrt(mean_squared_error(y_test,etr_test)))
# Out:
# r2 score -0.1617225693082318
# r2 score on training data 99.99436237912519
# mean absolute error 4.928824517212426
# mean squared error 41.261351203470475
# mean root sqaured error 6.423499918538995

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,LR_test)) - (score.mean()*100))
# Out:
# [0.10804617 0.11831373 0.07235752 0.13915067 0.13291506]
# 0.11415663065110941
# Difference between r2 score and cross validation score is- -11.289064186222026

# %%
score1= cross_val_score(rfr,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,rfr_test)) - (score.mean()*100))
# Out:
# [0.20511203 0.13400579 0.04057603 0.09729889 0.09845817]
# 0.11509018075699266
# Difference between r2 score and cross validation score is- -11.377570376540596

# %%
score2=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,knn_test))-(score2.mean()*100))
# Out:
# [0.17197591 0.04939783 0.06714048 0.08884042 0.08034729]
# 0.09154038826598862
# Difference between r2 score and cross validation score is- -9.161888033259979

# %%
score3=cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,gbr_test))-(score3.mean()*100))
# Out:
# [0.25371189 0.27252474 0.16964246 0.20040388 0.19626966]
# 0.21851052652175543
# Difference between r2 score and cross validation score is- -21.68595985017213

# %%
score4=cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,lasso_test))-(score4.mean()*100))
# Out:
# [ 0.01015415  0.00985562 -0.02890057 -0.00461369 -0.0037284 ]
# -0.0034465787842842934
# Difference between r2 score and cross validation score is- 0.35168416732718333

# %%
score5=cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,rdg_test))-(score3.mean()*100))
# Out:
# [0.10820833 0.1184582  0.0720978  0.13924516 0.13291498]
# 0.11418489179290277
# Difference between r2 score and cross validation score is- -21.724535343922742

# %%
score6=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,dtr_test))-(score3.mean()*100))
# Out:
# [-0.33023257 -0.59007376 -0.39814621 -0.49690215 -0.49316248]
# -0.46170343424410465
# Difference between r2 score and cross validation score is- -22.313599500435416

# %%
score7=cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,svr_test))-(score3.mean()*100))
# Out:
# [0.17455856 0.13526336 0.08288492 0.19745668 0.15860732]
# 0.14975416828707175
# Difference between r2 score and cross validation score is- -21.710843653142053

# %%
score8=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,etr_test))-(score3.mean()*100))
# Out:
# [ 0.09613848 -0.03841772 -0.11983307 -0.06919638 -0.06358407]
# -0.038978552059354056
# Difference between r2 score and cross validation score is- -22.012775221483775

# %%
from sklearn.model_selection import GridSearchCV

# %%
para={'learning_rate':[0.1],'n_estimators':[100],
      'subsample':[1.0],'criterion':('squared_error','friedman_mse','absolute_error','poisson'),
     
      }
gscv=GridSearchCV(GradientBoostingRegressor(),para,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ('squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'),
#                          'learning_rate': [0.1], 'n_estimators': [100],
#                          'subsample': [1.0]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'n_estimators': 100,
#  'subsample': 1.0}

# %%
model=GradientBoostingRegressor(criterion= 'squared_error',learning_rate = 0.1, n_estimators= 100,subsample= 1.0)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2 score',r2_score(y_test,pred))
print('mean absolute error',mean_absolute_error(y_test,pred))
print('mean squared error', mean_squared_error(y_test,pred))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score 0.16301901392693052
# mean absolute error 4.295242605508766
# mean squared error 29.72737840287669
# root mean squared error 5.452281944550987

# %%
import pickle

# %%
filename='medical_cost_insurance.pkl'
pickle.dump(model,open('medical_cost_insurance.pkl','wb'))

# %%
loaded_model=pickle.load(open('medical_cost_insurance.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 16.301901392693054

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],(y_test)[:]],index=['Predicted','Original'])
conclusion
# Out:
#                  0          1          2          3          4          5    \
# Predicted  29.572391  24.015937  31.963199  30.172471  30.175277  28.260392
# Original   28.000000  28.000000  39.000000  21.000000  30.000000  19.000000
#
#                  6          7          8         9    ...        387  \
# Predicted  30.643059  32.729655  31.806821  26.24858  ...  24.231689
# Original   27.000000  37.000000  24.000000  27.00000  ...  29.000000
#
#                  388        389        390        391        392        393  \
# Predicted  34.399133  24.665792  25.507954  29.337989  27.923312  32.317246
# Original   35.000000  24.000000  24.000000  22.000000  22.000000  29.000000
#
#                  394        395        396
# Predicted  32.498165  29.892661  34.250772
# Original   21.000000  30.000000  38.000000
#
# [2 rows x 397 columns]
