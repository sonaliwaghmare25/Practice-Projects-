# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Practice Projects\Project Datasets\Students Grades Prediction-3rd phase.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.sample()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 368  CS-97369     B+      A      A        B+      A     A-     A-      B
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 368      A  ...      A     C+      A      B    NaN     A-      B      A
#
#     CS-412   CGPA
# 368     A-  3.437
#
# [1 rows x 43 columns]

# %%
df.shape
# Out:
# (571, 43)

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
df.nunique()
# Out:
# Seat No.     571
# PH-121        13
# HS-101        12
# CY-105        13
# HS-105/12     13
# MT-111        13
# CS-105        11
# CS-106        13
# EL-102        13
# EE-119        12
# ME-107        13
# CS-107        14
# HS-205/20     13
# MT-222        14
# EE-222        13
# MT-224        14
# CS-210        14
# CS-211        14
# CS-203        13
# CS-214        13
# EE-217        13
# CS-212        12
# CS-215        14
# MT-331        12
# EF-303        12
# HS-304        14
# CS-301        12
# CS-302        11
# TC-383        12
# MT-442        12
# EL-332        13
# CS-318        14
# CS-306        13
# CS-312        14
# CS-317        12
# CS-403        11
# CS-421        13
# CS-406        14
# CS-414        13
# CS-419        12
# CS-423        12
# CS-412        13
# CGPA         491
# dtype: int64

# %%
df['PH-121']=le.fit_transform(df['PH-121'])

# %%
df['HS-101']=le.fit_transform(df['HS-101'])

# %%
df['CY-105']=le.fit_transform(df['CY-105'])

# %%
df['HS-105/12']=le.fit_transform(df['HS-105/12'])

# %%
df['MT-111']=le.fit_transform(df['MT-111'])

# %%
df['CS-105']=le.fit_transform(df['CS-105'])

# %%
df['CS-106']=le.fit_transform(df['CS-106'])

# %%
df['EL-102']=le.fit_transform(df['EL-102'])

# %%
df['EE-119']=le.fit_transform(df['EE-119'])

# %%
df['ME-107']=le.fit_transform(df['ME-107'])

# %%
df['CS-107']=le.fit_transform(df['CS-107'])

# %%
df['HS-205/20']=le.fit_transform(df['HS-205/20'])

# %%
df['MT-222']=le.fit_transform(df['MT-222'])

# %%
df['EE-222']=le.fit_transform(df['EE-222'])

# %%
df['MT-224']=le.fit_transform(df['MT-224'])

# %%
df['CS-210']=le.fit_transform(df['CS-210'])

# %%
df['CS-211']=le.fit_transform(df['CS-211'])

# %%
df['CS-203']=le.fit_transform(df['CS-203'])

# %%
df['CS-214']=le.fit_transform(df['CS-214'])

# %%
df['EE-217']=le.fit_transform(df['EE-217'])

# %%
df['CS-212']=le.fit_transform(df['CS-212'])

# %%
df['CS-215']=le.fit_transform(df['CS-215'])

# %%
df['MT-331']=le.fit_transform(df['MT-331'])

# %%
df['EF-303']=le.fit_transform(df['EF-303'])

# %%
df['HS-304']=le.fit_transform(df['HS-304'])

# %%
df['CS-301']=le.fit_transform(df['CS-301'])

# %%
df['CS-302']=le.fit_transform(df['CS-302'])

# %%
df['TC-383']=le.fit_transform(df['TC-383'])

# %%
df['MT-442']=le.fit_transform(df['MT-442'])

# %%
df['EL-332']=le.fit_transform(df['EL-332'])

# %%
df['CS-318']=le.fit_transform(df['CS-318'])

# %%
df['CS-306']=le.fit_transform(df['CS-306'])

# %%
df['CS-312']=le.fit_transform(df['CS-312'])

# %%
df['CS-317']=le.fit_transform(df['CS-317'])

# %%
df['CS-403']=le.fit_transform(df['CS-403'])

# %%
df['CS-421']=le.fit_transform(df['CS-421'])

# %%
df['CS-406']=le.fit_transform(df['CS-406'])

# %%
df['CS-414']=le.fit_transform(df['CS-414'])

# %%
df['CS-419']=le.fit_transform(df['CS-419'])

# %%
df['CS-423']=le.fit_transform(df['CS-423'])

# %%
df['CS-412']=le.fit_transform(df['CS-412'])

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       5      10       8          6       8      10       9
# 1    CS-97002       0       9      10          9       5       6       9
# 2    CS-97003       0       3       0          5       4       0       5
# 3    CS-97004       9       7      10          9       9       2      10
# 4    CS-97005       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567       3       0       0          2       1       0       2
# 567  CS-97568       1       0       0          0       0       0       0
# 568  CS-97569       3       0       2          4       0       0       0
# 569  CS-97570       0       4       9          0       9      10       5
# 570  CS-97571       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121         int32
# HS-101         int32
# CY-105         int32
# HS-105/12      int32
# MT-111         int32
# CS-105         int32
# CS-106         int32
# EL-102         int32
# EE-119         int32
# ME-107         int32
# CS-107         int32
# HS-205/20      int32
# MT-222         int32
# EE-222         int32
# MT-224         int32
# CS-210         int32
# CS-211         int32
# CS-203         int32
# CS-214         int32
# EE-217         int32
# CS-212         int32
# CS-215         int32
# MT-331         int32
# EF-303         int32
# HS-304         int32
# CS-301         int32
# CS-302         int32
# TC-383         int32
# MT-442         int32
# EL-332         int32
# CS-318         int32
# CS-306         int32
# CS-312         int32
# CS-317         int32
# CS-403         int32
# CS-421         int32
# CS-406         int32
# CS-414         int32
# CS-419         int32
# CS-423         int32
# CS-412         int32
# CGPA         float64
# ...

# %% [markdown]
# Now we have converted all the column data into numerical form.

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap also shows that there are no null values present in the data.

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.781086    5.071804    2.921191    4.264448    3.935201    2.838879
# std      3.046895    2.785317    2.992228    3.216478    3.034481    2.696709
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    5.000000    7.000000    6.000000    4.000000
# max     12.000000   11.000000   13.000000   13.000000   13.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.161121    3.998249    3.921191    4.817863  ...    4.299475
# ...

# %% [markdown]
# from the above description, we can see that, mean is more than median in almost all the columns, which shows the presence of skewness.
#
# we can see that, the difference between 75% ans max values large, so the the possibility of presence of outliers in the data.
#
# we can see the other details from the above description as , min, std, count and 25% values of the data.

# %%
sns.heatmap(df.describe())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.565773   0.508231  0.487830  0.609990
# HS-101     0.382436  1.000000  0.334536   0.473146  0.441847  0.400713
# CY-105     0.565773  0.334536  1.000000   0.516758  0.554936  0.587845
# HS-105/12  0.508231  0.473146  0.516758   1.000000  0.505049  0.493581
# MT-111     0.487830  0.441847  0.554936   0.505049  1.000000  0.416784
# CS-105     0.609990  0.400713  0.587845   0.493581  0.416784  1.000000
# CS-106     0.319649  0.321346  0.404763   0.516214  0.528063  0.310666
# EL-102     0.443420  0.359801  0.466034   0.373136  0.568940  0.377496
# EE-119     0.589250  0.323381  0.501859   0.425518  0.422151  0.522205
# ME-107     0.548820  0.345819  0.485183   0.334125  0.478874  0.464978
# CS-107     0.501814  0.507674  0.501331   0.550732  0.503985  0.530578
# HS-205/20  0.338530  0.200494  0.325533   0.224536  0.372303  0.229860
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can see positive relation almost all the features. But still we need to check for presence of outliers in the data.

# %%
sns.regplot(df['PH-121'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='PH-121', ylabel='CGPA'>

# %%
sns.regplot(df['HS-101'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='HS-101', ylabel='CGPA'>

# %%
sns.regplot(df['CY-105'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='CY-105', ylabel='CGPA'>

# %%
sns.regplot(df['HS-105/12'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='HS-105/12', ylabel='CGPA'>

# %%
sns.regplot(df['MT-111'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='MT-111', ylabel='CGPA'>

# %%
sns.regplot(df['CS-105'],df['CGPA'])
# Out:
# <AxesSubplot:xlabel='CS-105', ylabel='CGPA'>

# %% [markdown]
# From the above regression plots, we can see the correlation between features and the target variable is almost same.

# %% [markdown]
# Now we will check the presence of outliers.

# %%
df.skew()
# Out:
# PH-121       0.549104
# HS-101       0.053303
# CY-105       1.001752
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# CS-412       1.086028
# ...

# %%
df['CY-105']=np.cbrt(df['CY-105'])

# %%
df['HS-205/20']=np.cbrt(df['HS-205/20'])

# %%
df['CS-406']=np.cbrt(df['CS-406'])

# %%
df['CS-414']=np.cbrt(df['CS-414'])

# %%
df['CS-412']=np.cbrt(df['CS-412'])

# %%
df.skew()
# Out:
# PH-121       0.549104
# HS-101       0.053303
# CY-105      -0.397919
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20   -0.958609
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406      -0.671251
# CS-414      -0.382579
# CS-419       0.773674
# CS-423       0.627219
# CS-412      -0.841460
# ...

# %%
df['PH-121'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HS-101'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CY-105'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HS-105/12'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MT-111'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-105'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-106'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EL-102'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EE-119'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ME-107'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-107'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HS-205/20'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MT-222'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EE-222'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MT-224'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-210'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-211'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-203'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-214'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EE-217'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-212'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CS-215'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MT-331'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EF-303'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above boxplots, we can see that, few features are showing presence of outliers in the data.

# %%
from scipy.stats import zscore
outliers=df[['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412', 'CGPA']]
z=np.abs(zscore(outliers))
z
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.400402  1.770900  1.215446   0.540054  1.340711  2.657832  1.745703
# 1    1.242052  1.411559  1.416605   1.473569  0.351207  1.173242  1.745703
# 2    1.242052  0.744483  1.389651   0.228883  0.021373  1.053643  0.302639
# 3    1.714365  0.692879  1.416605   1.473569  1.670546  0.311348  2.106468
# 4    0.585070  1.103823  0.251457   0.082289  1.297966  1.053643  0.779659
# ..        ...       ...       ...        ...       ...       ...       ...
# 566  0.256579  1.822504  1.389651   0.704632  0.968131  1.053643  0.779659
# 567  0.913561  1.822504  1.389651   1.326975  1.297966  1.053643  1.501191
# 568  0.256579  1.822504  0.251457   0.082289  1.297966  1.053643  1.501191
# 569  1.242052  0.385142  1.319759   1.326975  1.670546  2.657832  0.302639
# 570  0.728893  1.411559  1.319759   0.540054  0.681042  2.657832  0.418893
#
# ...

# %%
np.where(z>3)
# Out:
# (array([ 44,  44,  44,  44,  44,  60,  60,  60,  91,  91, 137, 137, 137,
#         137, 142, 142, 142, 142, 143, 143, 143, 143, 143, 281, 281, 281,
#         282, 288, 288, 288, 288, 288, 565, 565, 565, 565, 565], dtype=int64),
#  array([ 6, 13, 15, 19, 24, 13, 15, 24, 15, 24, 13, 15, 19, 24, 13, 15, 19,
#         24, 13, 15, 19, 24, 41,  6, 24, 41, 24, 13, 15, 19, 24, 41, 13, 15,
#         19, 24, 41], dtype=int64))

# %%
z.iloc[44,6]
# Out:
# 3.1887662020669527

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (561, 43)

# %%
print('Old data shape',df.shape)
print('New data shape',df1.shape)
# Out:
# Old data shape (571, 43)
# New data shape (561, 43)

# %%
print('Data loss percentage',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage 1.7513134851138354

# %% [markdown]
# The above mentioned data loss is easily affordable.

# %%
Q1=df1.quantile(.25)
Q3=df1.quantile(.75)
IQR=Q3-Q1
Q1
# Out:
# PH-121       2.000000
# HS-101       3.000000
# CY-105       0.000000
# HS-105/12    2.000000
# MT-111       2.000000
# CS-105       0.000000
# CS-106       2.000000
# EL-102       2.000000
# EE-119       2.000000
# ME-107       2.000000
# CS-107       1.000000
# HS-205/20    1.259921
# MT-222       2.000000
# EE-222       1.000000
# MT-224       2.000000
# CS-210       2.000000
# CS-211       2.000000
# CS-203       2.000000
# CS-214       2.000000
# EE-217       2.000000
# CS-212       2.000000
# CS-215       2.000000
# MT-331       1.000000
# EF-303       2.000000
# HS-304       2.000000
# CS-301       2.000000
# CS-302       2.000000
# TC-383       2.000000
# MT-442       1.000000
# EL-332       2.000000
# CS-318       3.000000
# CS-306       2.000000
# CS-312       1.000000
# CS-317       3.000000
# CS-403       1.000000
# CS-421       3.000000
# CS-406       1.259921
# CS-414       0.000000
# CS-419       2.000000
# CS-423       2.000000
# CS-412       1.259921
# ...

# %%
Q3
# Out:
# PH-121       6.000000
# HS-101       7.000000
# CY-105       1.587401
# HS-105/12    7.000000
# MT-111       6.000000
# CS-105       4.000000
# CS-106       5.000000
# EL-102       6.000000
# EE-119       6.000000
# ME-107       7.000000
# CS-107       7.000000
# HS-205/20    1.587401
# MT-222       8.000000
# EE-222       5.000000
# MT-224       7.000000
# CS-210       5.000000
# CS-211       7.000000
# CS-203       7.000000
# CS-214       7.000000
# EE-217       5.000000
# CS-212       6.000000
# CS-215       7.000000
# MT-331       6.000000
# EF-303       6.000000
# HS-304       6.000000
# CS-301       6.000000
# CS-302       5.000000
# TC-383       7.000000
# MT-442       4.000000
# EL-332       6.000000
# CS-318       7.000000
# CS-306       6.000000
# CS-312       7.000000
# CS-317       7.000000
# CS-403       5.000000
# CS-421       7.000000
# CS-406       1.817121
# CS-414       1.587401
# CS-419       5.000000
# CS-423       6.000000
# CS-412       1.817121
# ...

# %%
Q1
# Out:
# PH-121       2.000000
# HS-101       3.000000
# CY-105       0.000000
# HS-105/12    2.000000
# MT-111       2.000000
# CS-105       0.000000
# CS-106       2.000000
# EL-102       2.000000
# EE-119       2.000000
# ME-107       2.000000
# CS-107       1.000000
# HS-205/20    1.259921
# MT-222       2.000000
# EE-222       1.000000
# MT-224       2.000000
# CS-210       2.000000
# CS-211       2.000000
# CS-203       2.000000
# CS-214       2.000000
# EE-217       2.000000
# CS-212       2.000000
# CS-215       2.000000
# MT-331       1.000000
# EF-303       2.000000
# HS-304       2.000000
# CS-301       2.000000
# CS-302       2.000000
# TC-383       2.000000
# MT-442       1.000000
# EL-332       2.000000
# CS-318       3.000000
# CS-306       2.000000
# CS-312       1.000000
# CS-317       3.000000
# CS-403       1.000000
# CS-421       3.000000
# CS-406       1.259921
# CS-414       0.000000
# CS-419       2.000000
# CS-423       2.000000
# CS-412       1.259921
# ...

# %%
IQR
# Out:
# PH-121       4.000000
# HS-101       4.000000
# CY-105       1.587401
# HS-105/12    5.000000
# MT-111       4.000000
# CS-105       4.000000
# CS-106       3.000000
# EL-102       4.000000
# EE-119       4.000000
# ME-107       5.000000
# CS-107       6.000000
# HS-205/20    0.327480
# MT-222       6.000000
# EE-222       4.000000
# MT-224       5.000000
# CS-210       3.000000
# CS-211       5.000000
# CS-203       5.000000
# CS-214       5.000000
# EE-217       3.000000
# CS-212       4.000000
# CS-215       5.000000
# MT-331       5.000000
# EF-303       4.000000
# HS-304       4.000000
# CS-301       4.000000
# CS-302       3.000000
# TC-383       5.000000
# MT-442       3.000000
# EL-332       4.000000
# CS-318       4.000000
# CS-306       4.000000
# CS-312       6.000000
# CS-317       4.000000
# CS-403       4.000000
# CS-421       4.000000
# CS-406       0.557200
# CS-414       1.587401
# CS-419       3.000000
# CS-423       4.000000
# CS-412       0.557200
# ...

# %%
df1_new=df1[(z<3).all(axis=1)]
df1_new
# Out:
#      Seat No.  PH-121  HS-101    CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       5      10  2.000000          6       8      10       9
# 1    CS-97002       0       9  2.154435          9       5       6       9
# 2    CS-97003       0       3  0.000000          5       4       0       5
# 3    CS-97004       9       7  2.154435          9       9       2      10
# 4    CS-97005       2       2  1.259921          4       0       0       2
# ..        ...     ...     ...       ...        ...     ...     ...     ...
# 566  CS-97567       3       0  0.000000          2       1       0       2
# 567  CS-97568       1       0  0.000000          0       0       0       0
# 568  CS-97569       3       0  1.259921          4       0       0       0
# 569  CS-97570       0       4  2.080084          0       9      10       5
# 570  CS-97571       6       9  2.080084          6       6      10       3
#
# ...

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=18:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# Here, we have cleared all the outliers from the data using zscore and IWR method. We can see from the above plots, all the features are showing almost normal distribution.

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(df['CGPA'],kde=True)
plt.show()

# %%
df1_new.skew()
# Out:
# PH-121       0.548530
# HS-101       0.063778
# CY-105      -0.397132
# HS-105/12    0.315948
# MT-111       0.436954
# CS-105       0.950416
# CS-106       0.608061
# EL-102       0.467380
# EE-119       0.551962
# ME-107       0.084175
# CS-107       0.381887
# HS-205/20   -1.005026
# MT-222       0.161608
# EE-222       0.727243
# MT-224       0.381075
# CS-210       0.651963
# CS-211       0.076102
# CS-203       0.243370
# CS-214       0.005906
# EE-217       0.679852
# CS-212       0.395867
# CS-215       0.117010
# MT-331       0.610275
# EF-303       0.354207
# HS-304       0.517696
# CS-301       0.384944
# CS-302       0.573926
# TC-383       0.313326
# MT-442       0.846345
# EL-332       0.436109
# CS-318       0.332377
# CS-306       0.402225
# CS-312       0.433263
# CS-317       0.171122
# CS-403       0.616434
# CS-421       0.178549
# CS-406      -0.676992
# CS-414      -0.420508
# CS-419       0.568589
# CS-423       0.541069
# CS-412      -0.851796
# ...

# %%
sns.distplot(df1_new['CGPA'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %%
x=df1_new.iloc[:,0:-1]
x
# Out:
#      Seat No.  PH-121  HS-101    CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       5      10  2.000000          6       8      10       9
# 1    CS-97002       0       9  2.154435          9       5       6       9
# 2    CS-97003       0       3  0.000000          5       4       0       5
# 3    CS-97004       9       7  2.154435          9       9       2      10
# 4    CS-97005       2       2  1.259921          4       0       0       2
# ..        ...     ...     ...       ...        ...     ...     ...     ...
# 566  CS-97567       3       0  0.000000          2       1       0       2
# 567  CS-97568       1       0  0.000000          0       0       0       0
# 568  CS-97569       3       0  1.259921          4       0       0       0
# 569  CS-97570       0       4  2.080084          0       9      10       5
# 570  CS-97571       6       9  2.080084          6       6      10       3
#
# ...

# %%
x.drop('Seat No.',axis=1,inplace=True)

# %%
y=df1_new.iloc[:,-1]
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 561, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (561, 41)
# (561,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.438976  1.791629  1.251844   0.579679  1.425749  2.742611  1.845475
# 1   -1.238582  1.431248  1.454911   1.533346  0.397230  1.225997  1.845475
# 2   -1.238582 -0.731041 -1.377956   0.261791  0.054390 -1.048924  0.348278
# 3    1.781023  0.710485  1.454911   1.533346  1.768589 -0.290617  2.219774
# 4   -0.567559 -1.091423  0.278714  -0.056098 -1.316969 -1.048924 -0.774619
# ..        ...       ...       ...        ...       ...       ...       ...
# 556 -0.232047 -1.812186 -1.377956  -0.691875 -0.974129 -1.048924 -0.774619
# 557 -0.903071 -1.812186 -1.377956  -1.327653 -1.316969 -1.048924 -1.523217
# 558 -0.232047 -1.812186  0.278714  -0.056098 -1.316969 -1.048924 -1.523217
# 559 -1.238582 -0.370660  1.357147  -1.327653  1.768589  2.742611  0.348278
# 560  0.774488  1.431248  1.357147   0.579679  0.740069  2.742611 -0.400320
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values   Features
# 0     2.856516     PH-121
# 1     1.790272     HS-101
# 2     2.184812     CY-105
# 3     2.246251  HS-105/12
# 4     2.623905     MT-111
# 5     2.333369     CS-105
# 6     1.952930     CS-106
# 7     1.967514     EL-102
# 8     2.220967     EE-119
# 9     2.306656     ME-107
# 10    2.358503     CS-107
# 11    1.538803  HS-205/20
# 12    2.265360     MT-222
# 13    2.312676     EE-222
# 14    2.829614     MT-224
# 15    3.145691     CS-210
# 16    2.578560     CS-211
# 17    2.552740     CS-203
# 18    2.715768     CS-214
# 19    2.413717     EE-217
# 20    2.818620     CS-212
# 21    2.984286     CS-215
# 22    2.005800     MT-331
# 23    2.136343     EF-303
# 24    2.590754     HS-304
# 25    3.097585     CS-301
# 26    2.762101     CS-302
# 27    2.952527     TC-383
# 28    1.972656     MT-442
# 29    3.205875     EL-332
# 30    2.425725     CS-318
# 31    3.449057     CS-306
# 32    3.278105     CS-312
# 33    3.282871     CS-317
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (392, 41)

# %%
x_test.shape
# Out:
# (169, 41)

# %%
y_train.shape
# Out:
# (392,)

# %%
y_test.shape
# Out:
# (169,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([1.97148901, 3.73466229, 2.33916598, 2.82773976, 3.11244245,
#        3.20604469, 2.48823279, 3.77519725, 3.81859725, 3.82213106,
#        3.27225619, 2.71400934, 3.36017671, 3.41292397, 3.17090647,
#        3.05987079, 2.53025305, 2.38921675, 3.57061058, 2.1825305 ,
#        2.35142045, 2.67246202, 3.26334782, 1.98329728, 2.79435789,
#        2.35630294, 2.86342655, 3.70847263, 3.21895735, 3.34143711,
#        3.34033397, 1.94349371, 2.71845959, 2.61922978, 2.53290721,
#        2.83161171, 2.94095801, 2.52156124, 2.73517156, 3.73012647,
#        2.84476936, 3.52021032, 2.6133616 , 2.63620499, 2.54198922,
#        3.76433881, 3.60121655, 2.75395695, 3.72043671, 3.92311885,
#        3.37616221, 3.68213866, 3.88291013, 2.34458194, 2.56847893,
#        3.16140151, 3.83986704, 2.25540064, 3.43687334, 2.9948185 ,
#        3.91533709, 3.28014287, 3.49140398, 2.46119727, 3.95202134,
#        3.84078224, 2.41720926, 2.93031757, 3.28233883, 3.23093502,
# ...

# %%
print(r2_score(pred,y_test))
print(mean_absolute_error(pred,y_test))
print(mean_squared_error(pred,y_test))
print(np.sqrt(mean_squared_error(pred,y_test)))
# Out:
# 0.9742907133928873
# 0.06427690250432097
# 0.009258469686683462
# 0.09622094203801718

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_rfr=rfr.predict(x_test)
pred_rfr
# Out:
# array([2.16452, 3.6602 , 2.65726, 2.80532, 3.2773 , 3.15989, 2.61239,
#        3.80268, 3.75922, 3.60451, 3.23732, 2.66805, 3.51103, 3.32751,
#        3.20485, 2.9793 , 2.57636, 2.56024, 3.39117, 2.28926, 2.3398 ,
#        2.63815, 3.38796, 2.2752 , 2.66342, 2.51222, 2.85055, 3.58745,
#        3.31008, 3.23264, 3.39632, 2.11958, 2.66053, 2.61698, 2.58319,
#        2.82963, 2.87696, 2.40132, 2.8072 , 3.68634, 2.94214, 3.44841,
#        2.62877, 2.75552, 2.52148, 3.68133, 3.44443, 2.69163, 3.70801,
#        3.76916, 3.38325, 3.4805 , 3.73783, 2.38292, 2.62945, 3.28427,
#        3.77031, 2.29978, 3.46011, 2.96526, 3.8001 , 3.19624, 3.50566,
#        2.58774, 3.9189 , 3.78524, 2.49698, 3.07853, 3.27538, 3.21281,
#        2.08608, 2.70303, 2.25564, 3.09979, 3.54915, 2.67035, 1.82207,
#        3.16241, 2.55847, 3.11518, 3.02989, 3.46008, 1.99139, 2.19627,
#        3.1296 , 2.07409, 2.53818, 3.56202, 3.62525, 2.67011, 3.06317,
# ...

# %%
print(r2_score(pred_rfr,y_test))
print(mean_absolute_error(pred_rfr,y_test))
print(mean_squared_error(pred_rfr,y_test))
print(np.sqrt(mean_squared_error(pred_rfr,y_test)))
# Out:
# 0.9297778782045631
# 0.09676041420118307
# 0.019865707539053187
# 0.14094576098291564

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred_knn=knn.predict(x_test)
pred_knn
# Out:
# array([1.9882, 3.8686, 2.343 , 2.7694, 3.2464, 3.2718, 2.5408, 3.8544,
#        3.759 , 3.6988, 3.2916, 2.9162, 3.5396, 3.4682, 3.1036, 3.1792,
#        2.5646, 2.4012, 3.456 , 2.118 , 2.3068, 2.6562, 3.3854, 1.9504,
#        2.7516, 2.4432, 3.0164, 3.6636, 3.2466, 3.3354, 3.3818, 1.8632,
#        2.7052, 2.6804, 2.6692, 2.8026, 2.9394, 2.596 , 3.0452, 3.6616,
#        2.7612, 3.506 , 2.6352, 2.6726, 2.5884, 3.9022, 3.653 , 2.727 ,
#        3.8746, 3.844 , 3.4358, 3.6326, 3.7766, 2.3742, 2.6166, 3.2434,
#        3.896 , 2.3596, 3.5036, 2.9844, 3.8478, 3.3796, 3.5194, 2.7016,
#        3.9178, 3.86  , 2.5018, 3.002 , 3.2662, 3.243 , 1.8926, 2.4128,
#        2.0814, 2.82  , 3.613 , 2.6558, 1.7606, 3.332 , 2.6432, 3.1496,
#        3.0466, 3.4702, 1.8628, 2.1234, 3.268 , 2.146 , 2.4238, 3.8478,
#        3.6588, 2.8232, 3.1628, 2.8964, 2.8294, 3.9412, 2.5532, 3.3976,
#        2.6328, 3.2514, 2.8434, 3.5424, 3.4364, 2.904 , 2.4848, 3.0546,
# ...

# %%
print(r2_score(pred_knn,y_test))
print(mean_absolute_error(pred_knn,y_test))
print(mean_squared_error(pred_knn,y_test))
print(np.sqrt(mean_squared_error(pred_knn,y_test)))
# Out:
# 0.9574481283070728
# 0.0845585798816568
# 0.01513867313609467
# 0.12303931540810308

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()

# %%
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred_gbr=gbr.predict(x_test)
pred_gbr
# Out:
# array([2.06679871, 3.61496604, 2.5671219 , 2.80335894, 3.25731214,
#        3.17814759, 2.56150291, 3.77129531, 3.78161721, 3.7171369 ,
#        3.21755879, 2.58169123, 3.47986871, 3.37787224, 3.23935459,
#        2.99457802, 2.57356219, 2.46049102, 3.421168  , 2.16911408,
#        2.46624423, 2.73166529, 3.42096095, 2.14816678, 2.64722057,
#        2.47624797, 2.87568842, 3.58728251, 3.22725821, 3.25733376,
#        3.38800521, 1.98138937, 2.63627054, 2.61298836, 2.60807563,
#        2.85833302, 2.80040878, 2.37930699, 2.87388717, 3.78017709,
#        2.95267815, 3.42002098, 2.66857664, 2.65444729, 2.55946751,
#        3.73206945, 3.48269833, 2.66752538, 3.72415876, 3.7778414 ,
#        3.42182514, 3.5309577 , 3.64314289, 2.30793217, 2.58903121,
#        3.31947268, 3.76568556, 2.24604204, 3.45033536, 2.96643565,
#        3.77576984, 3.2738058 , 3.54245548, 2.4032051 , 3.93355375,
#        3.80316283, 2.42707282, 3.02561443, 3.23038964, 3.29972821,
# ...

# %%
print(r2_score(pred_gbr,y_test))
print(mean_absolute_error(pred_gbr,y_test))
print(mean_squared_error(pred_gbr,y_test))
print(np.sqrt(mean_squared_error(pred_gbr,y_test)))
# Out:
# 0.9548404834613746
# 0.09131963476188992
# 0.014789829020541937
# 0.12161344095346507

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
pred_lasso=lasso.predict(x_test)
pred_lasso
# Out:
# array([3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
#        3.00006378, 3.00006378, 3.00006378, 3.00006378, 3.00006378,
# ...

# %%
print(r2_score(pred_lasso,y_test))
print(mean_absolute_error(pred_lasso,y_test))
print(mean_squared_error(pred_lasso,y_test))
print(np.sqrt(mean_squared_error(pred_lasso,y_test)))
# Out:
# -1.924765351944445e+30
# 0.5158428782755706
# 0.37959303446823356
# 0.6161112192358077

# %%
from sklearn.linear_model import Ridge

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
# Out:
# Ridge()

# %%
pred_rdg=rdg.predict(x_test)
pred_rdg
# Out:
# array([1.9718016 , 3.73416932, 2.3388068 , 2.82781928, 3.11233218,
#        3.20601779, 2.48858548, 3.77517271, 3.8185311 , 3.82191408,
#        3.27170106, 2.71371296, 3.36039043, 3.41298765, 3.1707499 ,
#        3.05965249, 2.53062324, 2.38948054, 3.57017561, 2.18195863,
#        2.3517508 , 2.67260041, 3.26322156, 1.98352854, 2.79427838,
#        2.35652286, 2.86374157, 3.70809754, 3.21859   , 3.34080253,
#        3.33999801, 1.94357253, 2.71825898, 2.61926751, 2.53327184,
#        2.83148074, 2.94062669, 2.52130241, 2.73543474, 3.73010589,
#        2.84463493, 3.52016161, 2.61353911, 2.63620185, 2.5423178 ,
#        3.76423749, 3.60140654, 2.75365307, 3.72022052, 3.92334748,
#        3.37606401, 3.68221462, 3.8824036 , 2.34399566, 2.56827299,
#        3.16154708, 3.83994317, 2.25510591, 3.4369185 , 2.99431997,
#        3.91529878, 3.28007021, 3.49118616, 2.46151375, 3.95189559,
#        3.84080083, 2.41723799, 2.93004831, 3.28237032, 3.23080966,
# ...

# %%
print(r2_score(pred_rdg,y_test))
print(mean_absolute_error(pred_rdg,y_test))
print(mean_squared_error(pred_rdg,y_test))
print(np.sqrt(mean_squared_error(pred_rdg,y_test)))
# Out:
# 0.9742996093560105
# 0.0642348034015364
# 0.009252372509188214
# 0.09618925360552609

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred_dtr=dtr.predict(x_test)
pred_dtr
# Out:
# array([2.206, 3.625, 2.26 , 2.484, 3.491, 3.332, 2.505, 3.873, 3.751,
#        3.648, 3.754, 2.655, 3.585, 3.182, 3.559, 2.851, 2.484, 2.619,
#        3.559, 2.328, 2.935, 2.406, 3.477, 2.57 , 3.075, 2.528, 2.655,
#        3.485, 3.44 , 3.269, 3.573, 1.714, 2.659, 2.621, 2.845, 3.019,
#        2.851, 2.298, 2.084, 3.73 , 3.226, 3.651, 2.484, 2.931, 2.49 ,
#        3.554, 3.597, 2.88 , 3.769, 3.769, 3.492, 3.816, 3.972, 2.749,
#        2.948, 3.366, 3.772, 2.3  , 3.499, 2.914, 3.868, 3.269, 3.208,
#        2.971, 3.97 , 3.707, 2.053, 3.195, 3.195, 3.058, 2.363, 2.58 ,
#        2.129, 3.149, 3.656, 2.851, 1.658, 3.164, 2.57 , 3.448, 3.396,
#        3.485, 1.992, 1.886, 2.956, 2.311, 2.328, 3.707, 3.648, 2.845,
#        3.339, 2.851, 3.075, 3.943, 2.621, 3.043, 2.75 , 3.258, 2.378,
#        3.258, 3.017, 2.57 , 2.254, 2.566, 2.378, 1.899, 1.905, 1.749,
#        2.128, 3.985, 3.164, 2.206, 3.207, 3.97 , 2.564, 3.189, 2.352,
# ...

# %%
print(r2_score(pred_dtr,y_test))
print(mean_absolute_error(pred_dtr,y_test))
print(mean_squared_error(pred_dtr,y_test))
print(np.sqrt(mean_squared_error(pred_dtr,y_test)))
# Out:
# 0.7999645912740301
# 0.20466272189349113
# 0.06727723076923077
# 0.25937854724173076

# %%
from sklearn.svm import SVR

# %%
svr=SVR()
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred_svr=svr.predict(x_test)
pred_svr
# Out:
# array([2.02335798, 3.60481415, 2.33290249, 2.85779525, 3.05841562,
#        3.11920369, 2.4674901 , 3.60606112, 3.52769884, 3.59128258,
#        3.01484364, 2.63303811, 3.33540641, 3.27223355, 3.09857598,
#        3.00423373, 2.46406441, 2.46582219, 3.48377666, 2.20089973,
#        2.45086846, 2.6835261 , 3.34032848, 2.1283948 , 2.7839266 ,
#        2.40312157, 2.91090437, 3.56053396, 3.1837168 , 3.17567896,
#        3.36428693, 1.92376498, 2.72460336, 2.61194926, 2.58968836,
#        2.78970958, 2.88954045, 2.43298975, 2.79010238, 3.70985389,
#        2.76444193, 3.54605215, 2.56996503, 2.65356491, 2.5426236 ,
#        3.59574182, 3.37783141, 2.73301679, 3.56866589, 3.72509619,
#        3.41715966, 3.52579881, 3.63307856, 2.18145944, 2.50854808,
#        3.26200216, 3.72533063, 2.27624529, 3.50162945, 2.96033484,
#        3.78812256, 3.26964361, 3.43763534, 2.46793019, 3.91024281,
#        3.6917403 , 2.35900783, 2.92805491, 3.22735042, 3.23287799,
# ...

# %%
print(r2_score(pred_svr,y_test))
print(mean_absolute_error(pred_svr,y_test))
print(mean_squared_error(pred_svr,y_test))
print(np.sqrt(mean_squared_error(pred_svr,y_test)))
# Out:
# 0.9363127154175055
# 0.09236481613211786
# 0.0193857331186728
# 0.1392326582331631

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
pred_etr=etr.predict(x_test)
pred_etr
# Out:
# array([2.17232, 3.65439, 2.51988, 2.84116, 3.10957, 3.16074, 2.6442 ,
#        3.80591, 3.77603, 3.62236, 3.1342 , 2.63225, 3.51244, 3.324  ,
#        3.19412, 2.97938, 2.60344, 2.58866, 3.44924, 2.27263, 2.24846,
#        2.62231, 3.40253, 2.23314, 2.70986, 2.47306, 2.85113, 3.56424,
#        3.26762, 3.19575, 3.34735, 2.08904, 2.66604, 2.62779, 2.57131,
#        2.84167, 2.81936, 2.47489, 2.7751 , 3.66935, 2.93417, 3.4532 ,
#        2.65215, 2.77063, 2.56489, 3.64756, 3.39758, 2.80828, 3.73694,
#        3.72595, 3.36853, 3.51258, 3.71132, 2.33684, 2.60974, 3.33556,
#        3.77342, 2.26433, 3.47494, 3.002  , 3.79332, 3.15757, 3.44661,
#        2.63692, 3.91346, 3.78589, 2.51774, 3.03601, 3.29002, 3.21507,
#        2.07686, 2.68032, 2.15657, 3.05298, 3.54662, 2.66418, 1.75424,
#        3.29251, 2.56439, 3.05779, 3.0394 , 3.4139 , 1.94873, 2.15048,
#        3.11844, 2.10989, 2.48476, 3.56759, 3.61781, 2.69173, 3.085  ,
# ...

# %%
print(r2_score(pred_etr,y_test))
print(mean_absolute_error(pred_etr,y_test))
print(mean_squared_error(pred_etr,y_test))
print(np.sqrt(mean_squared_error(pred_etr,y_test)))
# Out:
# 0.9377843101634329
# 0.09554005917159737
# 0.017859306773372743
# 0.13363871734408686

# %% [markdown]
# From the above model fitting and performance score, we can say that, Linear Regression ans Ridge are the best fitting and best performing models, which are giving almost same performance score as 97.429

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred,y_test)) - (score.mean()*100))
# Out:
# [0.98180953 0.98756274 0.97690859 0.97942689 0.96770031]
# 0.978681611030272
# Difference between r2 score and cross validation score is- -96.8938703896343

# %%
score1= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rfr,y_test)) - (score.mean()*100))
# Out:
# [0.96710433 0.9672633  0.95679312 0.9599351  0.93678892]
# 0.9575769518142998
# Difference between r2 score and cross validation score is- -96.93838322482263

# %%
score2= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_knn,y_test)) - (score.mean()*100))
# Out:
# [0.96710433 0.9672633  0.95679312 0.9599351  0.93678892]
# 0.9575769518142998
# Difference between r2 score and cross validation score is- -96.91071297472011

# %%
score3= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_gbr,y_test)) - (score.mean()*100))
# Out:
# [0.95908463 0.9671324  0.95742555 0.96767217 0.96344214]
# 0.9629513802072
# Difference between r2 score and cross validation score is- -96.91332061956582

# %%
score4= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_lasso,y_test)) - (score.mean()*100))
# Out:
# [-0.00544748 -0.00616251 -0.00118298 -0.00021321 -0.02958288]
# -0.008517812268742198
# Difference between r2 score and cross validation score is- -1.924765351944445e+30

# %%
score5= cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rdg,y_test)) - (score.mean()*100))
# Out:
# [0.98187091 0.98759406 0.97695528 0.97944924 0.96773547]
# 0.9787209940457554
# Difference between r2 score and cross validation score is- -96.89386149367118

# %%
score6= cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_dtr,y_test)) - (score.mean()*100))
# Out:
# [0.85565209 0.81633066 0.79708562 0.78564002 0.76578383]
# 0.8040984436924612
# Difference between r2 score and cross validation score is- -97.06819651175316

# %%
score7= cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_svr,y_test)) - (score.mean()*100))
# Out:
# [0.95616951 0.97631577 0.96543843 0.95877515 0.95187236]
# 0.9617142462702211
# Difference between r2 score and cross validation score is- -96.93184838760969

# %%
score8= cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_etr,y_test)) - (score.mean()*100))
# Out:
# [0.96093067 0.9638504  0.96005675 0.95779365 0.95100478]
# 0.9587272473271167
# Difference between r2 score and cross validation score is- -96.93037679286375

# %% [markdown]
# From the above difference between r2 score and cross validation score, we can conclude that, LinearRegression is the best fitting and performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
para={'fit_intercept':[True,False],
        'n_jobs':[None],'copy_X':[True,False],
       
        }
gscv=GridSearchCV(LinearRegression(),para,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None}

# %%
model=LinearRegression(copy_X= True,fit_intercept= True,n_jobs= None)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2score:',r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:', mean_squared_error(y_test,pred))
print('roor mean squared error;',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score: 0.9752436286770675
# mean absolute error: 0.06427690250432097
# mean squared error: 0.009258469686683462
# roor mean squared error; 0.09622094203801718

# %%
import pickle

# %%
filename='Students_Grade_Prediction_LR.pkl'
pickle.dump(model,open('Students_Grade_Prediction_LR.pkl','wb'))

# %%
loaded_model=pickle.load(open('Students_Grade_Prediction_LR.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 97.52436286770674

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],(y_test)[:]],index=['Predicted','Original'])
conclusion
# Out:
#                 0         1         2        3         4         5    \
# Predicted  1.971489  3.734662  2.339166  2.82774  3.112442  3.206045
# Original   1.806000  3.714000  2.311000  2.86100  3.184000  3.217000
#
#                 6         7         8         9    ...       159       160  \
# Predicted  2.488233  3.775197  3.818597  3.822131  ...  3.890236  3.036094
# Original   2.599000  3.765000  3.758000  3.734000  ...  3.840000  3.019000
#
#                 161     162       163      164       165       166       167  \
# Predicted  3.219437  2.0217  2.185538  2.59007  2.738395  2.041309  2.535936
# Original   3.253000  2.0340  2.003000  2.57600  2.779000  1.993000  2.603000
#
#                168
# Predicted  3.11123
# Original   3.01000
#
# [2 rows x 169 columns]
