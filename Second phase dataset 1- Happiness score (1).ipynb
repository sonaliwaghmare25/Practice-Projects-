# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Practice Projects\Project Datasets\happiness_score_dataset - 2nd phase.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample()
# Out:
#    Country                      Region  Happiness Rank  Happiness Score  \
# 86  Serbia  Central and Eastern Europe              87            5.123
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 86         0.04864                   0.92053  1.00964
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 86                   0.74836  0.20107                        0.02617
#
#     Generosity  Dystopia Residual
# 86     0.19231              2.025

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# From the above column details we can see, the Happiness score is the dependent variables and Country, Region,Happiness Rank, Standard Error,Economy,Family, Freedom, Health, Trust, Generosity and Dystopia Residual are the independent variables

# %% [markdown]
# Here, we need to move the column 'Happiness Score' at the end of the dataset in place of 'Dystopia Residual'.

# %%
new_cols=(['Country', 'Region', 'Happiness Rank', 'Dystopia Residual',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Happiness Score'])
df=df[new_cols]

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Dystopia Residual  Standard Error  Economy (GDP per Capita)   Family  \
# 0              2.51738         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Dystopia Residual                float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Happiness Score                  float64
# dtype: object

# %%
df=df.replace({'Region':{'Sub-Saharan Africa':0,'Central and Eastern Europe':1,'Latin America and Caribbean':2,
                         'Western Europe':3,'Middle East and Northern Africa':4,'Southeastern Asia':5,'Southern Asia':6,
                         'Eastern Asia':7,'North America':8,'Australia and New Zealand':9}})
df
# Out:
#          Country  Region  Happiness Rank  Dystopia Residual  Standard Error  \
# 0    Switzerland       3               1            2.51738         0.03411
# 1        Iceland       3               2            2.70201         0.04884
# 2        Denmark       3               3            2.49204         0.03328
# 3         Norway       3               4            2.46531         0.03880
# 4         Canada       8               5            2.45176         0.03553
# ..           ...     ...             ...                ...             ...
# 153       Rwanda       0             154            0.67042         0.03464
# 154        Benin       0             155            1.63328         0.03656
# 155        Syria       4             156            0.32858         0.05015
# 156      Burundi       0             157            1.83302         0.08658
# 157         Togo       0             158            1.56726         0.06727
#
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Dystopia Residual                0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Happiness Score                  0
# dtype: int64

# %% [markdown]
# From the above code, we can see that, there are no null values present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    int64
#  2   Happiness Rank                 158 non-null    int64
#  3   Dystopia Residual              158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Happiness Score                158 non-null    float64
# ...

# %%
df.nunique().to_frame('Total unique values')
# Out:
#                                Total unique values
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Dystopia Residual                              158
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Happiness Score                                157

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# 0    40
# 1    29
# 2    22
# 3    21
# 4    20
# 5     9
# 6     7
# 7     6
# 8     2
# 9     2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 2.51738    1
# 2.51767    1
# 1.80101    1
# 1.57059    1
# 1.24074    1
#           ..
# 2.24729    1
# 1.61583    1
# 2.44649    1
# 2.32407    1
# 1.56726    1
# Name: Dystopia Residual, Length: 158, dtype: int64
#
#
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# ...

# %%
df.describe()
# Out:
#            Region  Happiness Rank  Dystopia Residual  Standard Error  \
# count  158.000000      158.000000         158.000000      158.000000
# mean     2.398734       79.493671           2.098977        0.047885
# std      2.225904       45.754363           0.553550        0.017146
# min      0.000000        1.000000           0.328580        0.018480
# 25%      0.250000       40.250000           1.759410        0.037268
# 50%      2.000000       79.500000           2.095415        0.043940
# 75%      4.000000      118.750000           2.462415        0.052300
# max      9.000000      158.000000           3.602140        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# ...

# %% [markdown]
# From the above description we can observe the following:
#
# Almost all the columns are having mean less than median.
#
# The counts of all the columns are same.
#
# As we can see, there is some difference between 75% and max values of all the columns, this shows that the outliers are present in the data.
#
# We can see the standard deviation, min and 25% values from the above data.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=2,linecolor='black',cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x='Dystopia Residual',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Standard Error',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Family',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Freedom',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Generosity',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Health (Life Expectancy)',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Rank',data=df)

# %%
sns.lmplot(x='Happiness Score',y='Happiness Rank',data=df)

# %%
sns.pairplot(data=df,palette='Dark')

# %% [markdown]
# Here, we cannot get the exact idea about outliers. We will try to find out the outliers with the help of zscore method.

# %%
from scipy.stats import zscore
outliers=df[['Region','Happiness Rank', 'Dystopia Residual',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity','Happiness Score']]
z=np.abs(zscore(outliers))
z
# Out:
#        Region  Happiness Rank  Dystopia Residual  Standard Error  \
# 0    0.270981        1.721000           0.758258        0.805926
# 1    0.270981        1.699075           1.092857        0.055889
# 2    0.270981        1.677149           0.712335        0.854487
# 3    0.270981        1.655224           0.663893        0.531526
# 4    2.524402        1.633299           0.639337        0.722845
# ..        ...             ...                ...             ...
# 153  1.081072        1.633576           2.588925        0.774917
# 154  1.081072        1.655501           0.843967        0.662582
# 155  0.721665        1.677427           3.208430        0.132534
# 156  1.081072        1.699352           0.481985        2.263962
# 157  1.081072        1.721277           0.963612        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([8, 3, 3, 3, 9, 5, 8, 2, 5], dtype=int64))

# %% [markdown]
# From the above zscore details we can see that few outliers are present in data.

# %%
z.iloc[40,1]
# Out:
# 0.8439865618127919

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (149, 12)

# %% [markdown]
# We have cleaned the outliers and now we have the new dataframe.

# %%
print('Old data shape',df.shape)
print('New data shape',df1.shape)
# Out:
# Old data shape (158, 12)
# New data shape (149, 12)

# %%
print('Data loss percentage',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage 5.69620253164557

# %% [markdown]
# The above data loss is absolutely affordable. Now we can check with IQR method.

# %%
Q1=outliers.quantile(0.25)
Q3=outliers.quantile(0.75)
IQR=Q3-Q1
df2=df[~((df<(Q1-1.5*IQR)))|(df>(Q3+1.5*IQR)).any(axis=1)]
df2
# Out:
#          Country  Region  Happiness Rank  Dystopia Residual  Standard Error  \
# 0    Switzerland       3               1            2.51738         0.03411
# 1        Iceland       3               2            2.70201         0.04884
# 2        Denmark       3               3            2.49204         0.03328
# 3         Norway       3               4            2.46531         0.03880
# 4         Canada       8               5            2.45176         0.03553
# ..           ...     ...             ...                ...             ...
# 153       Rwanda       0             154                NaN         0.03464
# 154        Benin       0             155            1.63328         0.03656
# 155        Syria       4             156                NaN         0.05015
# 156      Burundi       0             157            1.83302         0.08658
# 157         Togo       0             158            1.56726         0.06727
#
# ...

# %% [markdown]
# From the above IQR calculations, we can see that there are few outliers still present.

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=16:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %%
q1=df['Generosity'].quantile(0.25)
q3=df['Generosity'].quantile(0.75)
IQR=q3-q1
low=q1-1.5*IQR
up=q3+1.5*IQR

up_array=np.where(df['Generosity']>=up)[0]
print(up_array)

df
# Out:
# [ 33 128]
#          Country  Region  Happiness Rank  Dystopia Residual  Standard Error  \
# 0    Switzerland       3               1            2.51738         0.03411
# 1        Iceland       3               2            2.70201         0.04884
# 2        Denmark       3               3            2.49204         0.03328
# 3         Norway       3               4            2.46531         0.03880
# 4         Canada       8               5            2.45176         0.03553
# ..           ...     ...             ...                ...             ...
# 153       Rwanda       0             154            0.67042         0.03464
# 154        Benin       0             155            1.63328         0.03656
# 155        Syria       4             156            0.32858         0.05015
# 156      Burundi       0             157            1.83302         0.08658
# 157         Togo       0             158            1.56726         0.06727
#
# ...

# %%
df[df['Generosity']>up].count()
# Out:
# Country                          2
# Region                           2
# Happiness Rank                   2
# Dystopia Residual                2
# Standard Error                   2
# Economy (GDP per Capita)         2
# Family                           2
# Health (Life Expectancy)         2
# Freedom                          2
# Trust (Government Corruption)    2
# Generosity                       2
# Happiness Score                  2
# dtype: int64

# %% [markdown]
# From the above data, firstly we have returned the rows, then with the help of count function , the total number of rows were 2.
#
# Now, we will do the trimmimg of the data, to remove all the bad data from the dataset.

# %%
new_df=df[df['Generosity']<up]
new_df.shape
# Out:
# (156, 12)

# %%
plt.figure(figsize=(18,12))
plt.subplot(5,4,3)
sns.histplot(df['Generosity'],kde=True)
plt.show()

# %%
new_df.skew()
# Out:
# Region                           0.890584
# Happiness Rank                   0.000277
# Dystopia Residual               -0.245749
# Standard Error                   1.965816
# Economy (GDP per Capita)        -0.325283
# Family                          -1.020854
# Health (Life Expectancy)        -0.706902
# Freedom                         -0.399774
# Trust (Government Corruption)    1.384694
# Generosity                       0.579524
# Happiness Score                  0.098838
# dtype: float64

# %% [markdown]
# We have dropped the 'Country column', as we are unable to convert it from object to int/float.

# %%
sns.distplot(df['Happiness Score'],color='r',kde_kws={'shade':True},hist=False)
plt.show()

# %%
df.corr()
# Out:
#                                  Region  Happiness Rank  Dystopia Residual  \
# Region                         1.000000       -0.391385          -0.059623
# Happiness Rank                -0.391385        1.000000          -0.521999
# Dystopia Residual             -0.059623       -0.521999           1.000000
# Standard Error                -0.329241        0.158516           0.083981
# Economy (GDP per Capita)       0.460236       -0.785267           0.040059
# Family                         0.163652       -0.733644           0.148117
# Health (Life Expectancy)       0.549154       -0.735613           0.018979
# Freedom                        0.281584       -0.556886           0.062783
# Trust (Government Corruption)  0.235666       -0.372315          -0.033105
# Generosity                     0.363412       -0.160142          -0.101301
# Happiness Score                0.392594       -0.992105           0.530474
#
# ...

# %%
plt.figure(figsize=(25,18))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.title('Descriptive Graph',fontsize=15)
plt.show()

# %%
df.corr().Generosity.sort_values()
# Out:
# Happiness Rank                  -0.160142
# Dystopia Residual               -0.101301
# Standard Error                  -0.088439
# Economy (GDP per Capita)        -0.010465
# Family                           0.087513
# Health (Life Expectancy)         0.108335
# Happiness Score                  0.180319
# Trust (Government Corruption)    0.276123
# Region                           0.363412
# Freedom                          0.373916
# Generosity                       1.000000
# Name: Generosity, dtype: float64

# %%
df=new_df.drop('Country',axis=1)

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']
print('Features Dimension',x.shape)
print('Target Dimension',y.shape)
# Out:
# Features Dimension (156, 10)
# Target Dimension (156,)

# %% [markdown]
# The above code shows the data separation in features and target variable.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        Region  Happiness Rank  Dystopia Residual  Standard Error  \
# 0    0.286733       -1.721392           0.752155       -0.808541
# 1    0.286733       -1.699454           1.086418        0.049407
# 2    0.286733       -1.677517           0.706278       -0.856885
# 3    0.286733       -1.655579           0.657884       -0.535372
# 4    2.545838       -1.633642           0.633353       -0.725833
# ..        ...             ...                ...             ...
# 151 -1.068730        1.635048          -2.591675       -0.777671
# 152 -1.068730        1.656985          -0.848465       -0.665841
# 153  0.738554        1.678923          -3.210560        0.125708
# 154 -1.068730        1.700860          -0.486845        2.247573
# 155 -1.068730        1.722798          -0.967991        1.122863
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.363014  1.320504                  1.256566  1.577027
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Values                       Features
# 0    1.855615                         Region
# 1   71.097968                 Happiness Rank
# 2   16.881006              Dystopia Residual
# 3    1.227560                 Standard Error
# 4   12.614007       Economy (GDP per Capita)
# 5    5.651020                         Family
# 6    8.180893       Health (Life Expectancy)
# 7    3.072658                        Freedom
# 8    1.997784  Trust (Government Corruption)
# 9    1.974787                     Generosity

# %%
x.drop('Happiness Rank',axis=1,inplace=True)
vif
# Out:
#    VIF Values                       Features
# 0    1.855615                         Region
# 1   71.097968                 Happiness Rank
# 2   16.881006              Dystopia Residual
# 3    1.227560                 Standard Error
# 4   12.614007       Economy (GDP per Capita)
# 5    5.651020                         Family
# 6    8.180893       Health (Life Expectancy)
# 7    3.072658                        Freedom
# 8    1.997784  Trust (Government Corruption)
# 9    1.974787                     Generosity

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Now we will create test trtain split

# %%
maxacc=0
maxrs=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print('maximum r2 score is :',maxacc,'on random state:',maxrs)
# Out:
# maximum r2 score is : 0.9999999617869768 on random state: 198

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
LR_test=LR.predict(x_test)
LR_train=LR.predict(x_train)
print('r2 score:',r2_score(y_test,LR_test))
print('r2 score on training data:',r2_score(y_train,LR_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,LR_test))
print('mean squared error:',mean_squared_error(y_test,LR_test))
print('root mean sqaured error:',np.sqrt(mean_squared_error(y_test,LR_test)))
# Out:
# r2 score: 0.9999998997672654
# r2 score on training data: 99.99999516158242
# mean absolute error: 0.00027702777820960256
# mean squared error: 9.751261407198333e-08
# root mean sqaured error: 0.00031227009794724717

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=LR_test,y=y_test,color='r')
plt.plot(LR_test,LR_test,color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('linear regression',fontsize=14)
plt.title('Linear Regression',fontsize=20)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_test=rfr.predict(x_test)
rfr_train=rfr.predict(x_train)
print('r2 score',r2_score(y_test,rfr_test))
print('r2 score on training data',r2_score(y_train,rfr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,rfr_test))
print('mean squared error',mean_squared_error(y_test,rfr_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,rfr_test)))
# Out:
# r2 score 0.8944373374247039
# r2 score on training data 98.4860863118201
# mean absolute error 0.24322042553191456
# mean squared error 0.10269789825957432
# root mean squared error 0.3204651279930069

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knn_test=knn.predict(x_test)
knn_train=knn.predict(x_train)
print('r2 score', r2_score(y_test,knn_test))
print('r2 score on training data',r2_score(y_train,knn_train)*100)
print('mean absolute error',mean_absolute_error(y_test,knn_test))
print('mean squared error',mean_squared_error(y_test,knn_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,knn_test)))
# Out:
# r2 score 0.8795175949525555
# r2 score on training data 92.62687850547647
# mean absolute error 0.2907106382978724
# mean squared error 0.11721274808510639
# root mean squared error 0.3423634736432997

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr_test=gbr.predict(x_test)
gbr_train=gbr.predict(x_train)
print('r2 score',r2_score(y_test,gbr_test))
print('r2 score on training data',r2_score(y_train,gbr_train)*100)
print('mean absolute error', mean_absolute_error(y_test,gbr_test))
print('mean squared error',mean_squared_error(y_test,gbr_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,gbr_test)))
# Out:
# r2 score 0.9154895231751559
# r2 score on training data 99.94191493365636
# mean absolute error 0.23017356588151275
# mean squared error 0.0822170276790369
# root mean squared error 0.28673511762432746

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
lasso_test=lasso.predict(x_test)
lasso_train=lasso.predict(x_train)
print('r2 score',r2_score(y_test,lasso_test))
print('r2 score on training data',r2_score(y_train,lasso_train)*100)
print('mean absolute error',mean_absolute_error(y_test,lasso_test))
print('mean squared error',mean_squared_error(y_test,lasso_test))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,lasso_test)))
# Out:
# r2 score -0.04252642215798352
# r2 score on training data 0.0
# mean absolute error 0.8016252195978917
# mean squared error 1.014234292918964
# root mean squared error 1.0070919982399642

# %%
from sklearn.linear_model import Ridge

# %%
rdg=Ridge()
rdg.fit(x_train,y_train)
rdg_test=rdg.predict(x_test)
rdg_train=rdg.predict(x_train)
print('r2_score',r2_score(y_test,rdg_test))
print('r2 score on training data',r2_score(y_train,rdg_train)*100)
print('mean absolute error',mean_absolute_error(y_test,rdg_test))
print('mean squared error',mean_squared_error(y_test,rdg_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,rdg_test)))
# Out:
# r2_score 0.9999354560118483
# r2 score on training data 99.99663774401743
# mean absolute error 0.006434128245521308
# mean squared error 6.279239047941253e-05
# root mean swuared error 0.007924164970481908

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr_test=dtr.predict(x_test)
dtr_train=dtr.predict(x_train)
print('r2_score',r2_score(y_test,dtr_test))
print('r2 score on training data',r2_score(y_train,dtr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,dtr_test))
print('mean squared error',mean_squared_error(y_test,dtr_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,dtr_test)))
# Out:
# r2_score 0.6933696298575193
# r2 score on training data 100.0
# mean absolute error 0.4213191489361703
# mean squared error 0.2983090212765958
# root mean swuared error 0.5461767308084406

# %%
from sklearn.svm import SVR

# %%
svr=SVR()
svr.fit(x_train,y_train)
svr_test=svr.predict(x_test)
svr_train=svr.predict(x_train)
print('r2_score',r2_score(y_test,svr_test))
print('r2 score on training data',r2_score(y_train,svr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,svr_test))
print('mean squared error',mean_squared_error(y_test,svr_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,svr_test)))
# Out:
# r2_score 0.917724378465366
# r2 score on training data 98.6729427952919
# mean absolute error 0.1543774159855025
# mean squared error 0.080042821992863
# root mean swuared error 0.2829184016511881

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
etr_test=etr.predict(x_test)
etr_train=etr.predict(x_train)
print('r2_score',r2_score(y_test,etr_test))
print('r2 score on training data',r2_score(y_train,etr_train)*100)
print('mean absolute error',mean_absolute_error(y_test,etr_test))
print('mean squared error',mean_squared_error(y_test,etr_test))
print('root mean swuared error',np.sqrt(mean_squared_error(y_test,etr_test)))
# Out:
# r2_score 0.9421779912865657
# r2 score on training data 100.0
# mean absolute error 0.1879402127659572
# mean squared error 0.05625283242340431
# root mean swuared error 0.23717679571029773

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,LR_test)) - (score.mean()*100))
# Out:
# [0.99999946 0.99999817 0.99999827 0.99999526 0.99999946]
# 0.9999981265131789
# Difference between r2 score and cross validation score is- -98.99981275155062

# %%
score1= cross_val_score(rfr,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,rfr_test)) - (score1.mean()*100))
# Out:
# [-7.34488776 -1.67502203 -1.05449205 -1.82548627 -6.16804547]
# -3.6135867178540715
# Difference between r2 score and cross validation score is- 362.2531091228318

# %%
score2=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,knn_test)) - (score2.mean()*100))
# Out:
# [-10.06032049  -3.4888588   -1.88963845  -4.0506523   -5.2439549 ]
# -4.946684988165541
# Difference between r2 score and cross validation score is- 495.54801641150664

# %%
score3=cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,gbr_test)) - (score3.mean()*100))
# Out:
# [-4.07640845 -0.52218519 -2.40335302 -2.63594324 -3.778234  ]
# -2.6832247768462576
# Difference between r2 score and cross validation score is- 269.2379672078009

# %%
score4=cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,lasso_test)) - (score4.mean()*100))
# Out:
# [-39.80029896 -13.36730095  -0.13851815 -30.06393117 -23.55142771]
# -21.38429538835132
# Difference between r2 score and cross validation score is- 2138.387012412974

# %%
score5=cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,rdg_test)) - (score5.mean()*100))
# Out:
# [0.99438241 0.99958512 0.99924711 0.99908086 0.99819765]
# 0.998098630084205
# Difference between r2 score and cross validation score is- -98.80992755240864

# %%
score6=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,dtr_test)) - (score6.mean()*100))
# Out:
# [ -5.74891997  -7.95077711 -13.74823237 -11.98206983  -7.10734528]
# -9.30746891125234
# Difference between r2 score and cross validation score is- 931.4402607550915

# %%
score7=cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,svr_test)) - (score7.mean()*100))
# Out:
# [-10.98718184   0.14951238   0.76801809  -0.29934148  -5.65439646]
# -3.2046778627462915
# Difference between r2 score and cross validation score is- 321.3855106530945

# %%
score8=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(y_test,etr_test)) - (score8.mean()*100))
# Out:
# [-6.35084644 -0.52259981 -0.95765624 -1.77931566 -5.48774451]
# -3.0196325339920156
# Difference between r2 score and cross validation score is- 302.9054313904881

# %% [markdown]
# From the above difference between r2 score and cross validation score, we can conclude that, LinearRegression is the best fitting and performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
para={'fit_intercept':[True,False],
        'n_jobs':[None],'copy_X':[True,False],
       
        }
gscv=GridSearchCV(LinearRegression(),para,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None}

# %%
model=LinearRegression(copy_X= True,fit_intercept= True,n_jobs= None)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2score:',r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:', mean_squared_error(y_test,pred))
print('roor mean squared error;',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score: 0.9999998997672654
# mean absolute error: 0.00027702777820960256
# mean squared error: 9.751261407198333e-08
# roor mean squared error; 0.00031227009794724717

# %%
import pickle

# %%
filename='Happiness_score.pkl'
pickle.dump(model,open('Happiness_score.pkl','wb'))

# %%
loaded_model=pickle.load(open('Happiness_score.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.99998997672654

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],(y_test)[:]],index=['Predicted','Original'])
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  5.128857  5.758588  5.097548  4.959349  4.948705  3.677859
# Original   5.129000  5.759000  5.098000  4.959000  4.949000  3.678000
#
#                  6         7         8         9   ...        37        38  \
# Predicted  5.790579  5.073323  5.193824  6.167673  ...  4.296625  5.770439
# Original   5.791000  5.073000  5.194000  6.168000  ...  4.297000  5.770000
#
#                  39        40       41        42        43        44  \
# Predicted  6.476765  5.715855  6.78621  4.694057  6.505054  5.192302
# Original   6.477000  5.716000  6.78600  4.694000  6.505000  5.192000
#
#                  45        46
# Predicted  3.994788  5.548079
# Original   3.995000  5.548000
#
# [2 rows x 47 columns]
