# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Practice Projects\Project Datasets\glass identification - 3rd phase.csv")
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
df.tail()
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# 209  211  1.51685  14.92   0.0  1.99  73.06  0.00  8.40  1.59     0.0    7
# 210  212  1.52065  14.36   0.0  2.02  73.42  0.00  8.44  1.64     0.0    7
# 211  213  1.51651  14.38   0.0  1.94  73.61  0.00  8.48  1.57     0.0    7
# 212  214  1.51711  14.23   0.0  2.08  73.36  0.00  8.62  1.67     0.0    7

# %%
df.sample()
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06   8.75  0.00  0.00.1  1.1
# 174  176  1.52119  12.97  0.33  1.51  73.39  0.13  11.27   0.0    0.28    5

# %%
df.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
df.rename(columns={'1':'Id number','1.52101':'refractive index','13.64':'Sodium','4.49':'Magnesium','1.10':'Aluminum',
                          '71.78':'Silicon','0.06':'Potassium','8.75':'Calcium','0.00':'Barium','0.00.1':'Iron','1.1':'Type of glass'},inplace=True)
df
# Out:
#      Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0            2           1.51761   13.89       3.60      1.36    72.73
# 1            3           1.51618   13.53       3.55      1.54    72.99
# 2            4           1.51766   13.21       3.69      1.29    72.61
# 3            5           1.51742   13.27       3.62      1.24    73.08
# 4            6           1.51596   12.79       3.61      1.62    72.97
# ..         ...               ...     ...        ...       ...      ...
# 208        210           1.51623   14.14       0.00      2.88    72.61
# 209        211           1.51685   14.92       0.00      1.99    73.06
# 210        212           1.52065   14.36       0.00      2.02    73.42
# 211        213           1.51651   14.38       0.00      1.94    73.61
# 212        214           1.51711   14.23       0.00      2.08    73.36
#
#      Potassium  Calcium  Barium  Iron  Type of glass
# 0         0.48     7.83    0.00  0.00              1
# ...

# %%
df.dtypes
# Out:
# Id number             int64
# refractive index    float64
# Sodium              float64
# Magnesium           float64
# Aluminum            float64
# Silicon             float64
# Potassium           float64
# Calcium             float64
# Barium              float64
# Iron                float64
# Type of glass         int64
# dtype: object

# %%
df.shape
# Out:
# (213, 11)

# %%
df.isnull().sum()
# Out:
# Id number           0
# refractive index    0
# Sodium              0
# Magnesium           0
# Aluminum            0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
df.nunique()
# Out:
# Id number           213
# refractive index    177
# Sodium              142
# Magnesium            93
# Aluminum            117
# Silicon             132
# Potassium            65
# Calcium             143
# Barium               34
# Iron                 32
# Type of glass         6
# dtype: int64

# %%
df['Type of glass'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# 212    7
# Name: Type of glass, Length: 213, dtype: int64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id number         213 non-null    int64
#  1   refractive index  213 non-null    float64
#  2   Sodium            213 non-null    float64
#  3   Magnesium         213 non-null    float64
#  4   Aluminum          213 non-null    float64
#  5   Silicon           213 non-null    float64
#  6   Potassium         213 non-null    float64
#  7   Calcium           213 non-null    float64
#  8   Barium            213 non-null    float64
#  9   Iron              213 non-null    float64
#  10  Type of glass     213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %% [markdown]
# From the above information, we can see that, there no null value present in the data.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above, heatmap also shows that there are no null values present in the data.

# %%
df.describe()
# Out:
#         Id number  refractive index      Sodium   Magnesium    Aluminum  \
# count  213.000000        213.000000  213.000000  213.000000  213.000000
# mean   108.000000          1.518353   13.406761    2.676056    1.446526
# std     61.631972          0.003039    0.818371    1.440453    0.499882
# min      2.000000          1.511150   10.730000    0.000000    0.290000
# 25%     55.000000          1.516520   12.900000    2.090000    1.190000
# 50%    108.000000          1.517680   13.300000    3.480000    1.360000
# 75%    161.000000          1.519150   13.830000    3.600000    1.630000
# max    214.000000          1.533930   17.380000    3.980000    3.500000
#
#           Silicon   Potassium     Calcium      Barium        Iron  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean    72.655023    0.499108    8.957934    0.175869    0.057277
# std      0.774052    0.653035    1.426435    0.498245    0.097589
# ...

# %% [markdown]
# From the above description, we can see that, in some columns the mean is less than median which shows the presence of skewness.
# We can also see that, the difference between 75% and max value is large in some columns, which means outliers are present in the data.
# The above details also gives us the idea about the standard deviation, count and min values of the data.

# %%
sns.heatmap(df.describe(),annot=True,linewidth=0.01,linecolor='black',cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                   Id number  refractive index    Sodium  Magnesium  Aluminum  \
# Id number          1.000000         -0.065721  0.380767  -0.647082  0.488475
# refractive index  -0.065721          1.000000 -0.193436  -0.128118 -0.405671
# Sodium             0.380767         -0.193436  1.000000  -0.276486  0.157928
# Magnesium         -0.647082         -0.128118 -0.276486   1.000000 -0.480035
# Aluminum           0.488475         -0.405671  0.157928  -0.480035  1.000000
# Silicon            0.052634         -0.540010 -0.068519  -0.160359 -0.009226
# Potassium         -0.002306         -0.287900 -0.265520   0.009397  0.324484
# Calcium            0.090257          0.812495 -0.275314  -0.444559 -0.260372
# Barium             0.451437          0.001062  0.327233  -0.492149  0.478936
# Iron              -0.078151          0.145791 -0.240802   0.086906 -0.076456
# Type of glass      0.878113         -0.161322  0.504983  -0.744004  0.597754
#
# ...

# %%
sns.heatmap(df.corr(),annot=True,linewidth=0.02,linecolor='black',cmap='Spectral')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can see that, almost all the features are positively correlated with each other except Magnesium.

# %%
sns.distplot(df['Id number'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Id number', ylabel='Density'>

# %%
sns.distplot(df['refractive index'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='refractive index', ylabel='Density'>

# %%
sns.distplot(df['Sodium'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Sodium', ylabel='Density'>

# %%
sns.distplot(df['Magnesium'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Magnesium', ylabel='Density'>

# %%
sns.distplot(df['Silicon'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Silicon', ylabel='Density'>

# %%
sns.distplot(df['Potassium'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Potassium', ylabel='Density'>

# %%
sns.distplot(df['Calcium'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Calcium', ylabel='Density'>

# %%
sns.distplot(df['Barium'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Barium', ylabel='Density'>

# %%
sns.distplot(df['Iron'],df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Iron', ylabel='Density'>

# %% [markdown]
# From the above plots, we can observe that Magnesium, Potassium and Iron are showing skewness.

# %%
df.skew()
# Out:
# Id number           0.000000
# refractive index    1.639658
# Sodium              0.457318
# Magnesium          -1.154323
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           6.549276
# Calcium             2.040591
# Barium              3.406749
# Iron                1.747173
# Type of glass       1.108861
# dtype: float64

# %%
df['refractive index']=np.sqrt(df['refractive index'])

# %%
df['Magnesium']=np.sqrt(df['Magnesium'])

# %%
df['Potassium']=np.sqrt(df['Potassium'])

# %%
df['Calcium']=np.sqrt(df['Calcium'])

# %%
df['Barium']=np.sqrt(df['Barium'])

# %%
df['Iron']=np.sqrt(df['Iron'])

# %%
df.skew()
# Out:
# Id number           0.000000
# refractive index    1.633370
# Sodium              0.457318
# Magnesium          -1.360233
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           0.865823
# Calcium             1.566901
# Barium              2.369065
# Iron                1.046027
# Type of glass       1.108861
# dtype: float64

# %%
df['refractive index']=np.log(df['refractive index'])

# %%
df['Calcium']=np.log(df['Calcium'])

# %%
df['Barium']=np.cbrt(df['Barium'])

# %%
df['Iron']=np.cbrt(df['Iron'])

# %%
df.skew()
# Out:
# Id number           0.000000
# refractive index    1.627092
# Sodium              0.457318
# Magnesium          -1.360233
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           0.865823
# Calcium             1.062738
# Barium              1.810219
# Iron                0.778191
# Type of glass       1.108861
# dtype: float64

# %%
df['Calcium']=np.cbrt(df['Calcium'])

# %%
df['Barium']=np.cbrt(df['Barium'])

# %%
df.skew()
# Out:
# Id number           0.000000
# refractive index    1.627092
# Sodium              0.457318
# Magnesium          -1.360233
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           0.865823
# Calcium             0.736782
# Barium              1.707278
# Iron                0.778191
# Type of glass       1.108861
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
df['Barium']=np.cbrt(df['Barium'])

# %%
df['refractive index']=boxcox(df['refractive index'],0)

# %%
df.skew()
# Out:
# Id number           0.000000
# refractive index    1.597312
# Sodium              0.457318
# Magnesium          -1.360233
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           0.865823
# Calcium             0.736782
# Barium              1.693728
# Iron                0.778191
# Type of glass       1.108861
# dtype: float64

# %% [markdown]
# from the above codes, we can have normalised the skewness of some features.

# %%
sns.pairplot(data=df, palette='Dark')

# %% [markdown]
# Now, we will check for the presence of outliers.

# %%
df['Id number'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['refractive index'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Sodium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Magnesium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Aluminum'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Silicon'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Silicon'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Calcium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Barium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Iron'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Type of glass'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# from the above, boxplot, we have onserved the presence of outliers in the data.

# %%
from scipy.stats import zscore
outliers=df[['Id number','refractive index','Sodium','Magnesium','Aluminum','Silicon','Potassium',
            'Calcium','Barium','Iron','Type of glass']]
z=np.abs(zscore(outliers))
z
# Out:
#      Id number  refractive index    Sodium  Magnesium  Aluminum   Silicon  \
# 0     1.723938          0.243248  0.591880   0.591973  0.173500  0.097091
# 1     1.707675          0.719079  0.150946   0.574216  0.187433  0.433777
# 2     1.691411          0.226638  0.240996   0.623627  0.313863  0.058303
# 3     1.675147          0.306383  0.167507   0.599041  0.414122  0.550322
# 4     1.658884          0.792420  0.755419   0.595510  0.347848  0.407878
# ..         ...               ...       ...        ...       ...       ...
# 208   1.658884          0.702416  0.898085   1.956080  2.874379  0.058303
# 209   1.675147          0.495948  1.853443   1.956080  1.089766  0.524423
# 210   1.691411          0.763267  1.167545   1.956080  1.149921  0.990604
# 211   1.707675          0.609137  1.192041   1.956080  0.989506  1.236644
# 212   1.723938          0.409449  1.008318   1.956080  1.270232  0.912907
#
#      Potassium   Calcium    Barium      Iron  Type of glass
# ...

# %%
np.where(z>3)
# Out:
# (array([105, 105, 105, 106, 106, 106, 109, 110, 111, 111, 162, 162, 162,
#         170, 170, 171, 171, 183, 183, 184, 185, 187, 200], dtype=int64),
#  array([1, 2, 5, 1, 5, 7, 7, 7, 1, 7, 4, 5, 7, 4, 6, 4, 6, 2, 5, 7, 7, 5,
#         5], dtype=int64))

# %%
z.iloc[106,1]
# Out:
# 5.081593397085364

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (200, 11)

# %% [markdown]
# After finding the outliers through zscore method,we have cleared those and the now we have a new dataset.

# %%
print('Old data shape',df.shape)
print('New data shape',df1.shape)
# Out:
# Old data shape (213, 11)
# New data shape (200, 11)

# %%
print('Data loss percentage',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage 6.103286384976526

# %% [markdown]
# The above data loss is affordable.

# %%
Q1=outliers.quantile(0.25)
Q3=outliers.quantile(0.75)
IQR=Q3-Q1
df2=df[~((df<(Q1-1.5*IQR)))|(df>(Q3+1.5*IQR)).any(axis=1)]
df2
# Out:
#      Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0            2         -1.567488   13.89   1.897367      1.36    72.73
# 1            3         -1.569751   13.53   1.884144      1.54    72.99
# 2            4         -1.567409   13.21   1.920937      1.29    72.61
# 3            5         -1.567789   13.27   1.902630      1.24    73.08
# 4            6         -1.570100   12.79   1.900000      1.62    72.97
# ..         ...               ...     ...        ...       ...      ...
# 208        210         -1.569672   14.14        NaN      2.88    72.61
# 209        211         -1.568690   14.92        NaN      1.99    73.06
# 210        212         -1.562703   14.36        NaN      2.02    73.42
# 211        213         -1.569228   14.38        NaN      1.94    73.61
# 212        214         -1.568279   14.23        NaN      2.08    73.36
#
#      Potassium   Calcium    Barium      Iron  Type of glass
# ...

# %% [markdown]
# As we can see, 'Refractive index' column is having negative values, we can drop it for smooth model functioning.

# %%
df2.drop('refractive index',axis=1,inplace=True)

# %% [markdown]
# From the above IQR calculations, we can see that there are few outliers still present.

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=16:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %%
q1=df['Type of glass'].quantile(0.25)
q3=df['Type of glass'].quantile(0.75)
iqr=q3-q1
low=q1-1.5*iqr
up=q3+1.5*iqr
up_array=np.where(df['Type of glass']>up)[0]
print(up_array)
df
# Out:
# [184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201
#  202 203 204 205 206 207 208 209 210 211 212]
#      Id number  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0            2         -1.567488   13.89   1.897367      1.36    72.73
# 1            3         -1.569751   13.53   1.884144      1.54    72.99
# 2            4         -1.567409   13.21   1.920937      1.29    72.61
# 3            5         -1.567789   13.27   1.902630      1.24    73.08
# 4            6         -1.570100   12.79   1.900000      1.62    72.97
# ..         ...               ...     ...        ...       ...      ...
# 208        210         -1.569672   14.14   0.000000      2.88    72.61
# 209        211         -1.568690   14.92   0.000000      1.99    73.06
# 210        212         -1.562703   14.36   0.000000      2.02    73.42
# 211        213         -1.569228   14.38   0.000000      1.94    73.61
# ...

# %%
df[df['Type of glass']>up].count()
# Out:
# Id number           29
# refractive index    29
# Sodium              29
# Magnesium           29
# Aluminum            29
# Silicon             29
# Potassium           29
# Calcium             29
# Barium              29
# Iron                29
# Type of glass       29
# dtype: int64

# %% [markdown]
# From the above data, firstly we have returned the rows, then with the help of count function , we can see the total number of rows as42.
#
# Now, we will do the trimmimg of the data, to remove all the bad data from the dataset.

# %%
new_df=df[df['Type of glass']<up]
new_df.shape
# Out:
# (175, 11)

# %% [markdown]
# Now we have cleared all the bad data. We will proceed further with new data.

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(df['Type of glass'],kde=True)
plt.show()

# %%
new_df.skew()
# Out:
# Id number           0.000000
# refractive index    1.820559
# Sodium             -0.775302
# Magnesium          -2.507488
# Aluminum            1.313538
# Silicon            -1.244025
# Potassium           2.183738
# Calcium             1.414672
# Barium              3.447299
# Iron                0.596275
# Type of glass       1.598856
# dtype: float64

# %%
new_df['Potassium']=boxcox(new_df['Potassium'],1)

# %%
new_df['Calcium']=boxcox(new_df['Calcium'],1)

# %%
new_df['refractive index']=np.cbrt(new_df['refractive index'])

# %%
new_df['Barium']=np.cbrt(new_df['Barium'])

# %%
new_df.skew()
# Out:
# Id number           0.000000
# refractive index    1.831681
# Sodium             -0.775302
# Magnesium          -2.507488
# Aluminum            1.313538
# Silicon            -1.244025
# Potassium           2.183738
# Calcium             1.414672
# Barium              3.444194
# Iron                0.596275
# Type of glass       1.598856
# dtype: float64

# %%
sns.distplot(new_df['Type of glass'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='Type of glass', ylabel='Density'>

# %%
x=new_df.iloc[:,0:-1]
x.drop('refractive index',axis=1,inplace=True)
x
# Out:
#      Id number  Sodium  Magnesium  Aluminum  Silicon  Potassium   Calcium  \
# 0            2   13.89   1.897367      1.36    72.73  -0.307180  0.009569
# 1            3   13.53   1.884144      1.54    72.99  -0.375500  0.008520
# 2            4   13.21   1.920937      1.29    72.61  -0.245017  0.017455
# 3            5   13.27   1.902630      1.24    73.08  -0.258380  0.014482
# 4            6   12.79   1.900000      1.62    72.97  -0.200000  0.014482
# ..         ...     ...        ...       ...      ...        ...       ...
# 170        172   13.02   0.000000      3.04    70.48   1.491987 -0.010071
# 171        173   13.00   0.000000      3.02    70.70   1.491987 -0.010806
# 172        174   13.38   0.000000      1.40    72.25  -0.425544  0.080900
# 173        175   12.85   1.268858      2.17    72.18  -0.128220  0.043440
# 174        176   12.97   0.574456      1.51    73.39  -0.639445  0.065917
#
#        Barium      Iron
# 0    0.000000  0.000000
# 1    0.000000  0.000000
# ...

# %% [markdown]
# As Potassium column is also showing some negative values, its better to drop it to smoothen the fuerther process.

# %%
y=new_df.iloc[:,-1]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 170    5
# 171    5
# 172    5
# 173    5
# 174    5
# Name: Type of glass, Length: 175, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (175, 9)
# (175,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF values   Features
# 0    5.334007  Id number
# 1  513.108706     Sodium
# 2   40.246439  Magnesium
# 3   37.348870   Aluminum
# 4  723.872044    Silicon
# 5    7.819508  Potassium
# 6   16.853140    Calcium
# 7    1.189976     Barium
# 8    1.698534       Iron

# %%
x.drop('Sodium',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (122, 8)

# %%
y_train.shape
# Out:
# (122,)

# %%
x_test.shape
# Out:
# (53, 8)

# %%
y_test.shape
# Out:
# (53,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtr=DecisionTreeClassifier()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtr.predict(x_test)
pred
# Out:
# array([3, 2, 2, 2, 2, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 1, 3, 2, 5,
#        2, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 2, 2, 5, 1, 2, 2, 1, 3, 1,
#        2, 3, 3, 2, 2, 1, 3, 2, 2], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.9811320754716981

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[23  0  0  0]
#  [ 0 21  0  0]
#  [ 0  1  6  0]
#  [ 0  0  0  2]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        23
#            2       0.95      1.00      0.98        21
#            3       1.00      0.86      0.92         7
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.98        53
#    macro avg       0.99      0.96      0.97        53
# weighted avg       0.98      0.98      0.98        53

# %%
def pred_dtr(p):
    p=p.reshape(1,-1)
    pred=dtr.predict(p)
    print('Response type',pred)
    if(pred==1):
        print('Building window')
    if(pred==2):
        print('Building non float window')
    if(pred==3):
        print('Vehicle window')
    elif(pred==4):
        print('Vehicle float window')
    elif(pred==5):
        print('containers')
    elif(pred==6):
        print('Tableware')
    elif(pred==7):
        print('Headlamp')

# %%
p=np.array([172,13.02,0.000000,3.04,70.48,1.491987,-0.010071,0.000000])
pred_dtr(p)

p=np.array([33,12.85,3.48,1.23,72.97,0.61,8.56,0.09])
pred_dtr(p)
# Out:
# Response type [3]
# Vehicle window
# Response type [1]
# Building window

# %%
from sklearn. svm import SVC

# %%
svc= SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=svc.predict(x_test)
pred
# Out:
# array([5, 2, 2, 2, 2, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 1, 5, 2, 5,
#        2, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 2, 2, 5, 1, 2, 2, 2, 2, 1,
#        2, 5, 5, 2, 2, 1, 5, 2, 2], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.8490566037735849

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[22  1  0  0]
#  [ 0 21  0  0]
#  [ 0  2  0  5]
#  [ 0  0  0  2]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        23
#            2       0.88      1.00      0.93        21
#            3       0.00      0.00      0.00         7
#            5       0.29      1.00      0.44         2
#
#     accuracy                           0.85        53
#    macro avg       0.54      0.74      0.59        53
# weighted avg       0.79      0.85      0.81        53

# %%
def pred_svc(p):
    p=p.reshape(1,-1)
    pred=svc.predict(p)
    print('Response type',pred)
    if(pred==1):
        print('Building window')
    if(pred==2):
        print('Building non float window')
    if(pred==3):
        print('Vehicle window')
    elif(pred==4):
        print('Vehicle float window')
    elif(pred==5):
        print('containers')
    elif(pred==6):
        print('Tableware')
    elif(pred==7):
        print('Headlamp')

# %%
p=np.array([6,12.79,1.900000,1.62,72.97,-0.200000,0.014482,0.000000])
pred_svc(p)
# Out:
# Response type [1]
# Building window

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
pred=gnb.predict(x_test)
pred
# Out:
# array([3, 3, 2, 2, 3, 2, 1, 1, 2, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 3, 2, 5,
#        2, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 3, 1,
#        2, 3, 3, 1, 2, 1, 3, 2, 2], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.9056603773584906

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[21  2  0  0]
#  [ 1 19  1  0]
#  [ 0  0  7  0]
#  [ 0  1  0  1]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.91      0.93        23
#            2       0.86      0.90      0.88        21
#            3       0.88      1.00      0.93         7
#            5       1.00      0.50      0.67         2
#
#     accuracy                           0.91        53
#    macro avg       0.92      0.83      0.85        53
# weighted avg       0.91      0.91      0.90        53

# %%
def pred_gnb(p):
    p=p.reshape(1,-1)
    pred=gnb.predict(p)
    print('Response type',pred)
    if(pred==1):
        print('Building window')
    if(pred==2):
        print('Building non float window')
    if(pred==3):
        print('Vehicle window')
    elif(pred==4):
        print('Vehicle float window')
    elif(pred==5):
        print('containers')
    elif(pred==6):
        print('Tableware')
    elif(pred==7):
        print('Headlamp')

# %%
p=np.array([6,12.79,1.900000,1.62,72.97,-0.200000,0.014482,0.000000])
pred_svc(p)
# Out:
# Response type [1]
# Building window

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lg.predict(x_test)
pred
# Out:
# array([3, 3, 2, 2, 2, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 1, 3, 2, 5,
#        2, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 2, 2, 5, 1, 2, 2, 1, 3, 1,
#        2, 3, 3, 2, 2, 1, 3, 2, 2], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[23  0  0  0]
#  [ 0 21  0  0]
#  [ 0  0  7  0]
#  [ 0  0  0  2]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00         2
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53

# %% [markdown]
# From the above model performance of DecisionTreeClassifier,SVC, GaussianNB, Logistic regression, we can confirm the best fitted and best performing model is Logistic regression. As, the Logistic regression model is giving 100% accuracy.

# %%
import joblib
joblib.dump(lg,'glass_identification_lg.obj')
# Out:
# ['glass_identification_lg.obj']

# %%
model=joblib.load('glass_identification_lg.obj')
model
# Out:
# LogisticRegression()
